# %% [markdown]
# # Arg classifier

# %%
import json
from nltk.tree import Tree
from nltk.tree import ParentedTree
from collections import defaultdict

# %%
with open('conll16st-en-01-12-16-train/relations.json', encoding='utf-8') as pdtb_file:
    relations = [json.loads(x) for x in pdtb_file];
    
with open('conll16st-en-01-12-16-train/parses.json', encoding='utf8') as parse_file:
    parses = json.load(parse_file)

# %%
# We only want explicit relations:

def explicit_relations(relations):
    '''Extract all explicit relations from the relations file'''
    relations_explicit = []

    for relation in relations:
        if relation['Type'] == 'Explicit':
            relations_explicit.append(relation)
    return (relations_explicit)

ex_relations = explicit_relations(relations)

# %%
# Seperate them into PS and SS relations

def ss_ps_relations(explicit_relations):
    '''
    Sort relations into same sentence and previous sentence relations
    '''
    
    relations_ss = []
    relations_ps = []
    #relations_other = []

    for relation in explicit_relations:
        sentence_id_arg1 = relation['Arg1']['TokenList'][0][3]
        sentence_id_connective = relation['Connective']['TokenList'][0][3]
        sentence_id_arg2 = relation['Arg2']['TokenList'][0][3]
    
        if sentence_id_arg1 == sentence_id_connective == sentence_id_arg2:
            relations_ss.append(relation)
        elif int(sentence_id_arg1) == int(sentence_id_connective) - 1 == int(sentence_id_arg2) -1:
            relations_ps.append(relation)
        #else: 
            #relations_other.append(relation)
            
    return relations_ss, relations_ps

ss_relations, ps_relations = ss_ps_relations(ex_relations)

# %%
def get_phrase_structure(docID, sentenceID):
    """
    Retrieve phrase_structure from the parses.json file by filename and sentenceID.
    """
         
    sentencelist = parses[docID]["sentences"]    
    phrase_structure = sentencelist[sentenceID]["parsetree"]
    
    return phrase_structure

# %% [markdown]
# # Output format

# %%
def get_constituent(docID,sentenceID,index,pos,token):
    """
    Finds parent node of input token. 
    """
    
    phrase_structure = get_phrase_structure(docID, sentenceID)    
    tree = Tree.fromstring(phrase_structure)    
    tree = ParentedTree.convert(tree)
    
    for subtree in tree.subtrees(filter=lambda x:
                                 x.label() == pos and x[0] == token):
        return subtree.parent().label()

#get_constituent("wsj_0204",6,0,"DT","The")

# %%
def get_upper_constituent():
    pass

# %%
featuresdict = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))

# %% [markdown]
# ### SS relations

# %%
tuplelist = []
featurelist = []

for relation in ss_relations[:20]:
    
    tokenlist = []
    sentencefeatures = []
    
    connective = relation["Connective"]["RawText"]
    connective_index = relation["Connective"]["TokenList"][0][4]
    docID = relation["DocID"]
    
    arg1_tokenlist = relation["Arg1"]["TokenList"]
    arg2_tokenlist = relation["Arg2"]["TokenList"]
    
    #retrieve phrase structure for sentence the argument is in
    arg1_sentenceID = arg1_tokenlist[0][3]
    arg1_phrase_structure = get_phrase_structure(docID, arg1_sentenceID)
    
    arg2_sentenceID = arg2_tokenlist[0][3]
    arg2_phrase_structure = get_phrase_structure(docID, arg2_sentenceID) #should be the same
    
    
    # Build a list with indices of words in the argument
    indices = []
    
    for wordspan in arg1_tokenlist:

        index = wordspan[4]        
        indices.append(index)

        
    # Every word that precedes the connective
    word_data = parses[docID]["sentences"][arg1_sentenceID]["words"][:connective_index]
    
    for index, word in enumerate(word_data):
        
        features = dict()
        
        pos = word[1]["PartOfSpeech"]
        token = word[0]
        
        if index in indices:
            argpart = True
        else:
            argpart = False
        
        constituent = get_constituent(docID,arg1_sentenceID,index,pos,token)
        
        #tokenlist.append(((word[0],argpart),pos,constituent,connective))
        
        
        
        features["pos"] = pos
        features["constituent"] = constituent
#         features["upper_constituent"] = FUNCTION
        
        features["connective"] = connective
        
        sentencefeatures.append(features)
        
        tokenlist.append((word[0], argpart))
        
        featuresdict[docID]["Sentences"][arg1_sentenceID].append({"token": word[0], "pos" : pos, "constituent" : constituent, "connective" : connective})
#         featuresdict[docID]["Sentences"][arg1_sentenceID].append({"features":{"constituent" : constituent}})
#         featuresdict[docID]["Sentences"][arg1_sentenceID].append({"features":{"connective" : connective}})
        
        
        
        
        
        
    
    
    featurelist.append(sentencefeatures)
    tuplelist.append(tokenlist)

# %%
json.dump(featuresdict, open("features.json", "w"), indent=4)

# %%
tuplelist
featurelist

# %%
tuplelist

# %% [markdown]
# ### PS relations

# %%
tuplelist = []
featurelist = []

for relation in ps_relations:
    
    tokenlist = []
    
    connective = relation["Connective"]["RawText"]
    connective_index = relation["Connective"]["TokenList"][0][4]
    docID = relation["DocID"]
    
    arg1_tokenlist = relation["Arg1"]["TokenList"]
    arg2_tokenlist = relation["Arg2"]["TokenList"]
    
    #retrieve phrase structure for sentence the argument is in
    arg1_sentenceID = arg1_tokenlist[0][3]
    arg1_phrase_structure = get_phrase_structure(docID, arg1_sentenceID)
    
    arg2_sentenceID = arg2_tokenlist[0][3]
    arg2_phrase_structure = get_phrase_structure(docID, arg2_sentenceID)
    
    
    # Build a list with indices of words in the argument
    indices = []
    
    for wordspan in arg1_tokenlist:

        index = wordspan[4]        
        indices.append(index)

        
    # Every word in the sentence 
    word_data = parses[docID]["sentences"][arg1_sentenceID]["words"]
    
    for index, word in enumerate(word_data):
        
        features = dict()
        
        pos = word[1]["PartOfSpeech"]
        token = word[0]
        
        if index in indices:
            argpart = True
        else:
            argpart = False
        
        constituent = get_constituent(docID,arg1_sentenceID,index,pos,token)
        
        #tokenlist.append(((word[0],argpart),pos,constituent,connective))
        
        
        
        features["pos"] = pos
        features["constituent"] = constituent
        features["connective"] = connective
        
        sentencefeatures.append(features)
        
        tokenlist.append((word[0], argpart))
    
    
    featurelist.append(sentencefeatures)
    tuplelist.append(tokenlist)

# %%
tuplelist

# %% [markdown]
# ## The classifier

# %%
import nltk

# %%
def arg_features(sentence, i, history, n_sent):
    
    features = featurelist[n_sent][i]
    #print(features)
    
    if i == 0:
        features["prev-word"] = "<START>"
        features["prev-tag"] = "<START>"
    else:
        features["prev-word"] = sentence[i-1]
        features["prev-tag"] = history[i-1]
        
#     print(features)
    return features

# %%
class ConsecutiveArgTagger(nltk.TaggerI):

    def __init__(self, train_sents):
        train_set = []
        for n_sent, tagged_sent in enumerate(train_sents):
            untagged_sent = nltk.tag.untag(tagged_sent)
#             print(untagged_sent)
            history = []
            for i, (word, tag) in enumerate(tagged_sent):
                featureset = arg_features(untagged_sent, i, history, n_sent)
                train_set.append( (featureset, tag) )
                history.append(tag)
        self.classifier = nltk.NaiveBayesClassifier.train(train_set)

    def tag(self, sentence):
        
        global count
        
        history = []
#         print(sentence,"\n")
        for i, word in enumerate(sentence):
            featureset = arg_features(sentence, i, history, count)
            tag = self.classifier.classify(featureset)
            history.append(tag)
            
        count += 1 #for the sentenceID
        
        return list(zip(sentence, history))

# %%
count = 0 #reset the sentenceID
tagger = ConsecutiveArgTagger(tuplelist)

# %%
size = int(len(tuplelist) * 0.1)

# %%
train_sents, test_sents = tuplelist[size:], tuplelist[:size]

# %%
print(tagger.evaluate(test_sents))
# Out:
# 0.6883632752550329

# %%
tagger.tag_sents(test_sents)
# Out:
# [[(('Under', False), False),
#   (('two', False), False),
#   (('new', False), False),
#   (('features', False), False),
#   ((',', False), False),
#   (('participants', False), False),
#   (('will', False), False),
#   (('be', False), False),
#   (('able', False), False),
#   (('to', False), False),
#   (('transfer', False), False),
#   (('money', False), False),
#   (('from', False), False),
#   (('the', False), False),
#   (('new', False), False),
#   (('funds', False), False),
#   (('to', False), False),
#   (('other', False), False),
#   (('investment', False), False),
#   (('funds', False), False),
#   (('or', True), False),
#   ((',', False), False)],
#  [(('Solo', True), False),
#   (('woodwind', True), False),
#   (('players', True), False),
#   (('have', True), False),
#   (('to', True), False),
#   (('be', True), False),
#   (('creative', True), False)],
#  [(('Solo', True), False),
#   (('woodwind', True), False),
#   (('players', True), False),
#   (('have', True), False),
#   (('to', True), False),
#   (('be', True), False),
#   (('creative', True), False),
#   (('if', True), False),
#   (('they', True), False),
#   (('want', True), False),
#   (('to', True), False),
#   (('work', True), False),
#   (('a', True), False),
#   (('lot', True), False),
#   ((',', False), False)],
#  [(('The', False), False),
#   (('oboist', False), False),
#   (('Heinz', False), False),
#   (('Holliger', False), False),
#   (('has', False), False),
#   (('taken', False), False),
#   (('a', False), False),
#   (('hard', False), False),
#   (('line', False), False),
#   (('about', False), False),
#   (('the', False), False),
#   (('problem', False), False),
#   ((':', False), False),
#   (('He', True), False),
#   (('commissions', True), False),
#   (('and', True), False),
#   (('splendidly', True), False),
#   (('interprets', True), False),
#   (('fearsome', True), False),
#   (('contemporary', True), False),
#   (('scores', True), False),
#   (('and', True), False),
#   (('does', True), False),
#   (('some', True), False),
#   (('conducting', True), False),
#   ((',', False), False)],
#  [(('Today', True), True),
#   ((',', True), False),
#   (('the', True), False),
#   (('pixie-like', True), False),
#   (('clarinetist', True), False),
#   (('has', True), False),
#   (('mostly', True), False),
#   (('dropped', True), False),
#   (('the', True), False),
#   (('missionary', True), False),
#   (('work', True), False),
#   (('-LRB-', False), False)],
#  [(('He', True), True),
#   (('believes', True), True),
#   (('in', True), True),
#   (('what', True), True),
#   (('he', True), True),
#   (('plays', True), True),
#   ((',', False), False)],
#  [(('Clad', False), False),
#   (('in', False), False),
#   (('his', False), False),
#   (('trademark', False), False),
#   (('black', False), False),
#   (('velvet', False), False),
#   (('suit', False), False),
#   ((',', False), False),
#   (('the', False), False),
#   (('soft-spoken', False), False),
#   (('clarinetist', False), False),
#   (('announced', False), False),
#   (('that', True), False),
#   (('his', True), False),
#   (('new', True), False),
#   (('album', True), False),
#   ((',', True), False),
#   (('``', True), False),
#   (('Inner', True), False),
#   (('Voices', True), False),
#   ((',', True), False),
#   (("''", True), False),
#   (('had', True), False),
#   (('just', True), False),
#   (('been', True), False),
#   (('released', True), False),
#   ((',', True), False),
#   (('that', True), False),
#   (('his', True), False),
#   (('family', True), False),
#   (('was', True), False),
#   (('in', True), False),
#   (('the', True), False),
#   (('front', True), False),
#   (('row', True), False),
#   ((',', False), False)],
#  [(('Clad', False), False),
#   (('in', False), False),
#   (('his', False), False),
#   (('trademark', False), False),
#   (('black', False), False),
#   (('velvet', False), False),
#   (('suit', False), False),
#   ((',', False), False),
#   (('the', False), False),
#   (('soft-spoken', False), False),
#   (('clarinetist', False), False),
#   (('announced', False), False),
#   (('that', False), False),
#   (('his', False), False),
#   (('new', False), False),
#   (('album', False), False),
#   ((',', False), False),
#   (('``', False), False),
#   (('Inner', False), False),
#   (('Voices', False), False),
#   ((',', False), False),
#   (("''", False), False),
#   (('had', False), False),
#   (('just', False), False),
#   (('been', False), False),
#   (('released', False), False),
#   ((',', False), False),
#   (('that', False), False),
#   (('his', False), False),
#   (('family', False), False),
#   (('was', False), False),
#   (('in', False), False),
#   (('the', False), False),
#   (('front', False), False),
#   (('row', False), False),
#   ((',', False), False),
#   (('and', True), False),
#   (('that', True), False),
#   (('it', True), False),
#   (('was', True), False),
#   (('his', True), False),
#   (('mother', True), False),
#   (("'s", True), False),
#   (('birthday', True), False),
#   ((',', False), False)],
#  [(('Then', True), True), ((',', False), False)],
#  [(('Mr.', True), False),
#   (('Stoltzman', True), False),
#   (('tied', True), False),
#   (('the', True), False),
#   (('composer', True), False),
#   (('in', True), False),
#   (('by', True), False),
#   (('proclaiming', True), False),
#   (('him', True), False),
#   (('``', True), False),
#   (('the', True), False),
#   (('great', True), False),
#   (('improviser', True), False),
#   (('of', True), False),
#   (('the', True), False),
#   (('18th', True), False),
#   (('century', True), False),
#   ((',', False), False),
#   (("''", False), False),
#   (('and', False), False)],
#  [(('Keeping', False), False),
#   (('the', False), False),
#   (('mood', False), False),
#   (('light', False), False),
#   ((',', False), False),
#   (('the', True), False),
#   (('two', True), False),
#   (('then', True), False),
#   (('chanted', True), False),
#   (('and', True), False),
#   (('chortled', True), False),
#   (('their', True), False),
#   (('way', True), False),
#   (('through', True), False),
#   (('some', True), False),
#   (('murderous', True), False),
#   (('polyrhythms', True), False),
#   ((',', False), False),
#   (('devised', False), False),
#   (('by', False), False),
#   (('Mr.', False), False),
#   (('Douglas', False), False),
#   (('as', False), False),
#   (('an', False), False),
#   (('alternative', False), False),
#   (('to', False), False),
#   (('Hindemith', False), False),
#   (("'s", False), False),
#   (('dry', False), False),
#   (('theory-teaching', False), False),
#   (('techniques', False), False),
#   ((',', False), False),
#   (('and', False), False)],
#  [(('It', True), True),
#   (('was', True), True),
#   (('all', True), True),
#   (('too', True), True),
#   (('mellow', True), True),
#   (('to', True), True),
#   (('be', True), True),
#   (('believed', True), True),
#   ((',', False), False)],
#  [(('Or', True), False), (('was', True), False), (('it', True), False)],
#  [(('Either', True), False),
#   (('way', True), False),
#   (('it', True), False),
#   (('was', True), False),
#   (('a', True), False),
#   (('pity', True), False),
#   ((',', False), False)],
#  [(('It', True), True),
#   (('was', True), True),
#   (('enjoyable', True), True),
#   (('to', True), True),
#   (('hear', True), True),
#   (('accomplished', True), True),
#   (('jazz', True), True),
#   (('without', True), True),
#   (('having', True), True),
#   (('to', True), True),
#   (('sit', True), True),
#   (('in', True), True),
#   (('a', True), True),
#   (('smoke-filled', True), True),
#   (('club', True), True),
#   ((',', False), False)],
#  [(('Managers', True), True),
#   (('and', True), True),
#   (('presenters', True), True),
#   (('insist', True), True),
#   (('that', True), True),
#   (('chamber', True), True),
#   (('music', True), True),
#   (('concerts', True), True),
#   (('are', True), True),
#   (('a', True), True),
#   (('hard', True), True),
#   (('sell', True), True),
#   ((',', False), False)],
#  [(('Managers', False), False),
#   (('and', False), False),
#   (('presenters', False), False),
#   (('insist', False), False),
#   (('that', False), False),
#   (('chamber', False), False),
#   (('music', False), False),
#   (('concerts', False), False),
#   (('are', False), False),
#   (('a', False), False),
#   (('hard', False), False),
#   (('sell', False), False),
#   ((',', False), False),
#   (('but', True), False),
#   (('can', True), False),
#   (('audiences', True), False),
#   (('really', True), False),
#   (('enjoy', True), False),
#   (('them', True), False)],
#  [(('The', True), False),
#   (('U.S.', True), False),
#   ((',', True), False),
#   (('along', True), False),
#   (('with', True), False),
#   (('Britain', True), False),
#   (('and', True), False),
#   (('Singapore', True), False),
#   ((',', True), False),
#   (('left', True), False),
#   (('the', True), False),
#   (('agency', True), False)],
#  [(('The', False), True),
#   (('personal', False), True),
#   (('antics', False), True),
#   (('of', False), True),
#   (('agency', False), True),
#   (('Director', False), True),
#   (('Amadou-Mahtar', False), True),
#   (("M'Bow", False), True),
#   (('drew', False), True),
#   (('much', False), True),
#   (('attention', False), True),
#   ((',', False), True),
#   (('such', False), True),
#   (('as', False), True),
#   (('when', True), True),
#   (('several', True), True),
#   (('of', True), True),
#   (('his', True), True),
#   (('top', True), True),
#   (('aides', True), True),
#   (('were', True), True),
#   (('uncovered', True), True),
#   (('as', True), True),
#   (('KGB', True), True),
#   (('plants', True), True),
#   (('and', True), True),
#   (('ejected', True), True),
#   (('from', True), True),
#   (('France', True), True)],
#  [(('The', True), False),
#   (('personal', True), False),
#   (('antics', True), False),
#   (('of', True), False),
#   (('agency', True), False),
#   (('Director', True), False),
#   (('Amadou-Mahtar', True), False),
#   (("M'Bow", True), False),
#   (('drew', True), False),
#   (('much', True), False),
#   (('attention', True), False),
#   ((',', False), False),
#   (('such', False), False),
#   (('as', False), False),
#   (('when', False), False),
#   (('several', False), False),
#   (('of', False), False),
#   (('his', False), False),
#   (('top', False), False),
#   (('aides', False), False),
#   (('were', False), False),
#   (('uncovered', False), False),
#   (('as', False), False),
#   (('KGB', False), False),
#   (('plants', False), False),
#   (('and', False), False),
#   (('ejected', False), False),
#   (('from', False), False),
#   (('France', False), False),
#   (('and', False), False)],
#  [(('The', False), False),
#   (('personal', False), False),
#   (('antics', False), False),
#   (('of', False), False),
#   (('agency', False), False),
#   (('Director', False), False),
#   (('Amadou-Mahtar', False), False),
#   (("M'Bow", False), False),
#   (('drew', False), False),
#   (('much', False), False),
#   (('attention', False), False),
#   ((',', False), False),
#   (('such', False), False),
#   (('as', False), False),
#   (('when', False), False),
#   (('several', False), False),
#   (('of', False), False),
#   (('his', False), False),
#   (('top', False), False),
#   (('aides', False), False),
#   (('were', False), False),
#   (('uncovered', False), False),
#   (('as', False), False),
#   (('KGB', False), False),
#   (('plants', False), False),
#   (('and', False), False),
#   (('ejected', False), False),
#   (('from', False), False),
#   (('France', False), False),
#   (('and', True), False),
#   (('when', True), False),
#   (('a', True), False),
#   (('mysterious', True), False),
#   (('office', True), False),
#   (('fire', True), False),
#   (('was', True), False),
#   (('set', True), False)],
#  [(('Mr.', True), True),
#   (("M'Bow", True), True),
#   (('was', True), True),
#   (('an', True), True),
#   (('extreme', True), True),
#   (('case', True), True),
#   ((',', False), False)],
#  [(('Glasnost', True), True),
#   (('may', True), True),
#   (('be', True), True),
#   (('partly', True), True),
#   (('responsible', True), True),
#   ((',', False), False)],
#  [(('Soviets', True), True),
#   (('remain', True), True),
#   (('in', True), True),
#   (('charge', True), True),
#   (('of', True), True),
#   (('education', True), True),
#   (('programs', True), True),
#   ((',', True), False),
#   (('a', True), False),
#   (('former', True), False),
#   (('head', True), False),
#   (('of', True), False),
#   (('an', True), False),
#   (('African', True), False),
#   (('military', True), False),
#   (('tribunal', True), False),
#   (('for', True), False),
#   (('executions', True), False),
#   (('is', True), False),
#   (('in', True), False),
#   (('charge', True), False),
#   (('of', True), False),
#   (('culture', True), False),
#   ((',', False), False)],
#  [(('Free', False), False),
#   (('markets', False), False),
#   ((',', False), False),
#   (('free', False), False),
#   (('minds', False), False),
#   (('and', False), False),
#   (('free', False), False),
#   (('elections', False), False),
#   (('have', False), False),
#   (('an', False), False),
#   (('appeal', False), False),
#   (('that', True), False),
#   (('seems', True), False),
#   (('to', True), False),
#   (('get', True), False),
#   (('muddled', True), False)],
#  [(('This', True), True),
#   (('can', True), True),
#   (('have', True), True),
#   (('its', True), True),
#   (('purposes', True), True),
#   (('at', True), True),
#   (('times', True), True),
#   ((',', False), False)],
#  [(('Such', True), False),
#   (('so-called', True), False),
#   (('male-sterile', True), False),
#   (('plants', True), False),
#   (('can', True), False),
#   (('then', True), False),
#   (('be', True), False),
#   (('fertilized', True), False),
#   (('by', True), False),
#   (('pollen', True), False),
#   (('from', True), False),
#   (('another', True), False),
#   (('strain', True), False),
#   (('of', True), False),
#   (('the', True), False),
#   (('plant', True), False),
#   ((',', False), False)],
#  [(('That', True), False), (("'s", True), False)],
#  [(('They', True), False),
#   (('sow', True), False),
#   (('a', True), False),
#   (('row', True), False),
#   (('of', True), False),
#   (('male-fertile', True), False),
#   (('plants', True), False),
#   (('nearby', True), False),
#   ((',', False), False),
#   (('which', False), False)],
#  [(('The', True), True),
#   (('first', True), True),
#   (('hybrid', True), True),
#   (('corn', True), True),
#   (('seeds', True), True),
#   (('produced', True), True),
#   (('using', True), True),
#   (('this', True), True),
#   (('mechanical', True), True),
#   (('approach', True), True),
#   (('were', True), True),
#   (('introduced', True), True),
#   (('in', True), True),
#   (('the', True), True),
#   (('1930s', True), True)],
#  [(('In', True), True),
#   (('China', True), True),
#   ((',', True), False),
#   (('a', True), False),
#   (('great', True), False),
#   (('number', True), False),
#   (('of', True), False),
#   (('workers', True), False),
#   (('are', True), False),
#   (('engaged', True), False),
#   (('in', True), False),
#   (('pulling', True), False),
#   (('out', True), False),
#   (('the', True), False),
#   (('male', True), False),
#   (('organs', True), False),
#   (('of', True), False),
#   (('rice', True), False),
#   (('plants', True), False),
#   (('using', True), False),
#   (('tweezers', True), False),
#   ((',', False), False)],
#  [(('The', True), False),
#   (('sterilizing', True), False),
#   (('gene', True), False),
#   (('is', True), False),
#   (('expressed', True), False)],
#  [(('The', True), True),
#   (('sterilizing', True), True),
#   (('gene', True), True),
#   (('is', True), True),
#   (('expressed', True), True),
#   (('just', True), True),
#   (('before', True), True),
#   (('the', True), True),
#   (('pollen', True), True),
#   (('is', True), True),
#   (('about', True), True),
#   (('to', True), True),
#   (('develop', True), True)],
#  [(('Both', True), False),
#   (('genes', True), False),
#   (('are', True), False),
#   (('then', True), False),
#   (('inserted', True), False),
#   (('into', True), False),
#   (('a', True), False),
#   (('few', True), False),
#   (('greenhouse', True), False),
#   (('plants', True), False),
#   ((',', False), False),
#   (('which', False), False),
#   (('are', False), False)],
#  [(('The', False), True),
#   (('laws', False), True),
#   (('of', False), True),
#   (('heredity', False), True),
#   (('dictate', False), True),
#   (('that', True), True),
#   (('half', True), True),
#   (('of', True), True),
#   (('the', True), True),
#   (('plants', True), True),
#   (('springing', True), True),
#   (('from', True), True),
#   (('these', True), True),
#   (('greenhouse-produced', True), True),
#   (('seeds', True), True),
#   (('will', True), True),
#   (('be', True), True),
#   (('male', True), True),
#   (('sterile', True), True),
#   (('and', True), True),
#   (('herbicide', True), True),
#   (('resistant', True), True)],
#  [(('He', False), False), (('said', False), False), (('that', True), False)],
#  [(('That', True), False), (("'s", True), False)],
#  [(('That', False), False),
#   (("'s", False), False),
#   (('because', True), False),
#   (('pollination', True), False),
#   ((',', False), False)],
#  [(('That', False), False),
#   (("'s", False), False),
#   (('because', False), False),
#   (('pollination', False), False),
#   ((',', False), False),
#   (('while', True), False),
#   (('easy', True), False),
#   (('in', True), False),
#   (('corn', True), False)],
#  [(('``', False), False),
#   (('It', False), False),
#   (("'s", False), False),
#   (('one', False), False),
#   (('thing', False), False),
#   (('to', False), False),
#   (('say', False), False),
#   (('you', True), False),
#   (('can', True), False),
#   (('sterilize', True), False),
#   ((',', False), False),
#   (('and', False), False),
#   (('another', False), False),
#   (('to', False), False)],
#  [(('Unwilling', True), False),
#   (('to', True), False),
#   (('put', True), False),
#   (('up', True), False),
#   (('new', True), False),
#   (('money', True), False),
#   (('for', True), False),
#   (('New', True), False),
#   (('Zealand', True), False)],
#  [(('Not', True), True),
#   (('only', True), True),
#   (('can', True), True),
#   (('they', True), True),
#   (('block', True), True),
#   (('Wellington', True), True),
#   (('from', True), True),
#   (('raising', True), True),
#   (('money', True), True),
#   (('in', True), True),
#   (('Japan', True), True),
#   ((',', False), False),
#   (('bankers', False), False),
#   (('here', False), False),
#   (('say', False), False),
#   ((',', False), False)],
#  [(('``', False), False),
#   (('I', True), False),
#   (('think', True), False),
#   (('it', True), False),
#   (('would', True), False),
#   (('be', True), False),
#   (('irresponsible', True), False)],
#  [(('Both', True), True),
#   (('sides', True), True),
#   (('are', True), True),
#   (('jealously', True), True),
#   (('guarding', True), True),
#   (('their', True), True),
#   (('turf', True), True),
#   ((',', False), False)],
#  [],
#  [],
#  [(('The', False), False),
#   (('league', False), False),
#   (('is', False), False),
#   (('the', False), False),
#   (('brainchild', False), False),
#   (('of', False), False),
#   (('Colorado', False), False),
#   (('real', False), False),
#   (('estate', False), False),
#   (('developer', False), False),
#   (('James', False), False),
#   (('Morley', False), False),
#   (('--', False), False),
#   (('once', False), False),
#   (('a', False), False),
#   (('minor-leaguer', False), False),
#   (('himself', False), False),
#   (('--', False), False),
#   (('who', False), False),
#   (('says', False), False),
#   (('he', True), False),
#   (('had', True), False),
#   (('the', True), False),
#   (('idea', True), False),
#   (('last', True), False),
#   (('January', True), False)],
#  [],
#  [(('-LRB-', False), False),
#   (('Players', False), False),
#   (('have', False), False),
#   (('to', False), False),
#   (('be', False), False),
#   (('35', False), False),
#   (('or', False), False),
#   (('older', False), False),
#   ((',', False), False),
#   (('except', False), False),
#   (('for', False), False),
#   (('catchers', False), False),
#   ((',', False), False),
#   (('who', True), False),
#   (('are', True), False),
#   (('eligible', True), False),
#   (('at', True), False),
#   (('32', True), False)],
#  [(('But', True), False)],
#  [(('Mr.', False), False),
#   (('Broberg', False), False),
#   ((',', False), False),
#   (('who', False), False),
#   (('started', False), False),
#   (('with', False), False),
#   (('the', False), False),
#   (('now-defunct', False), False),
#   (('Washington', False), False),
#   (('Senators', False), False),
#   ((',', False), False),
#   (('says', False), False),
#   (('that', True), False)],
#  [(('``', False), False),
#   (('It', True), False),
#   (('does', True), False),
#   (("n't", True), False),
#   (('replace', True), False),
#   (('pitching', True), False),
#   (('in', True), False),
#   (('the', True), False),
#   (('majors', True), False),
#   ((',', False), False)],
#  [(('``', False), False),
#   (('It', False), False),
#   (('does', False), False),
#   (("n't", False), False),
#   (('replace', False), False),
#   (('pitching', False), False),
#   (('in', False), False),
#   (('the', False), False),
#   (('majors', False), False),
#   ((',', False), False),
#   (('but', False), False),
#   (('it', False), False),
#   (('proves', False), False),
#   (('to', False), False),
#   (('me', False), False),
#   (('that', True), False),
#   (('I', True), False),
#   (('would', True), False),
#   (('have', True), False),
#   (('been', True), False),
#   (('able', True), False),
#   (('to', True), False),
#   (('play', True), False)],
#  [(('These', True), True),
#   (('days', True), True),
#   (('he', True), True),
#   (('hustles', True), True),
#   (('to', True), True),
#   (('house-painting', True), True),
#   (('jobs', True), True),
#   (('in', True), True),
#   (('his', True), True),
#   (('Chevy', True), True),
#   (('pickup', True), True)],
#  [],
#  [(('Worse', False), True),
#   ((',', False), False),
#   (('says', False), False),
#   (('baseball', False), False),
#   (('author', False), False),
#   (('Lawrence', False), False),
#   (('Ritter', False), False),
#   ((',', False), False),
#   (('``', False), False),
#   (('Someone', True), False),
#   (('will', True), False),
#   (('get', True), False),
#   (('a', True), False),
#   (('heart', True), False),
#   (('attack', True), False)],
#  [(('-LRB-', False), False),
#   (('No', True), False),
#   (('one', True), False),
#   (('has', True), False),
#   (('worked', True), False),
#   (('out', True), False),
#   (('the', True), False),
#   (('players', True), False),
#   (("'", True), False),
#   (('average', True), False),
#   (('age', True), False),
#   ((',', False), False)],
#  [(('``', False), False),
#   (('I', False), False),
#   (("'m", False), False),
#   (('not', False), False),
#   (('going', False), False),
#   (('to', False), False),
#   (('look', False), False),
#   (('stupid', False), False),
#   ((',', False), False),
#   (("''", False), False),
#   (('vows', False), False),
#   (('former', False), False),
#   (('Pittsburgh', False), False),
#   (('Pirate', False), False),
#   (('second', False), False),
#   (('baseman', False), False),
#   (('Rennie', False), False),
#   (('Stennett', False), False),
#   ((',', False), False),
#   (('sweat', True), False),
#   (('dotting', True), False),
#   (('his', True), False),
#   (('brow', True), False)],
#  [(('Even', False), False),
#   (('expect', False), False),
#   (('stolen', False), False),
#   (('bases', False), False),
#   ((',', False), False),
#   (('says', False), False),
#   (('the', False), False),
#   (('wiry', False), False),
#   (('and', False), False),
#   (('fit', False), False),
#   (('Mr.', False), False),
#   (('Campaneris', False), False),
#   ((':', False), False),
#   (('``', False), False)],
#  [(('``', False), False),
#   (('I', True), False),
#   (('wo', True), False),
#   (("n't", True), False),
#   (('be', True), False),
#   (('throwing', True), False),
#   (('90', True), False),
#   (('mph', True), False),
#   ((',', False), False)],
#  [(('People', False), False),
#   (("'s", False), False),
#   (('Savings', False), False),
#   (('Financial', False), False),
#   (('Corp.', False), False),
#   (('said', False), False),
#   (('it', True), False),
#   (('will', True), False),
#   (('buy', True), False),
#   (('back', True), False),
#   (('as', True), False),
#   (('much', True), False),
#   (('as', True), False),
#   (('10', True), False),
#   (('%', True), False),
#   (('of', True), False),
#   (('its', True), False),
#   (('2.4', True), False),
#   (('million', True), False),
#   (('shares', True), False),
#   (('outstanding', True), False)],
#  [(('Trade', False), False),
#   (('and', False), False),
#   (('Industry', False), False),
#   (('Secretary', False), False),
#   (('Nicholas', False), False),
#   (('Ridley', False), False),
#   (('told', False), False),
#   (('the', False), False),
#   (('House', False), False),
#   (('of', False), False),
#   (('Commons', False), False),
#   (('yesterday', False), False),
#   (('that', True), False),
#   (('he', True), False),
#   (('will', True), False),
#   (('relinquish', True), False),
#   (('the', True), False),
#   (('government', True), False),
#   (("'s", True), False),
#   (('so-called', True), False),
#   (('golden', True), False),
#   (('share', True), False),
#   (('in', True), False),
#   (('the', True), False),
#   (('company', True), False)],
#  [(('The', True), False),
#   (('share', True), False),
#   (('price', True), False),
#   (('was', True), False),
#   (('languishing', True), False),
#   (('at', True), False),
#   (('about', True), False),
#   (('400', True), False),
#   (('pence', True), False)],
#  [(('``', False), False),
#   (('It', True), False),
#   (("'s", True), False),
#   (('either', True), False),
#   (('going', True), False),
#   (('to', True), False),
#   (('be', True), False),
#   (('a', True), False),
#   (('shootout', True), False),
#   ((',', False), False)],
#  [(('Another', False), False),
#   (('person', False), False),
#   (('close', False), False),
#   (('to', False), False),
#   (('the', False), False),
#   (('talks', False), False),
#   (('said', False), False),
#   ((',', False), False),
#   (('``', False), False),
#   (('It', True), False),
#   (('is', True), False),
#   (('very', True), False),
#   (('hard', True), False),
#   (('to', True), False),
#   (('justify', True), False),
#   (('paying', True), False),
#   (('a', True), False),
#   (('silly', True), False),
#   (('price', True), False),
#   (('for', True), False),
#   (('Jaguar', True), False)],
#  [(('Jaguar', True), False),
#   (("'s", True), False),
#   (('own', True), False),
#   (('defenses', True), False),
#   (('against', True), False),
#   (('a', True), False),
#   (('hostile', True), False),
#   (('bid', True), False),
#   (('are', True), False),
#   (('weakened', True), False),
#   ((',', False), False),
#   (('analysts', False), False),
#   (('add', False), False),
#   ((',', False), False)],
#  [],
#  [(('Jaguar', True), False),
#   (('was', True), False),
#   (('shocked', True), False),
#   (('by', True), False),
#   (('Mr.', True), False),
#   (('Ridley', True), False),
#   (("'s", True), False),
#   (('decision', True), False),
#   ((',', False), False)],
#  [(('The', True), True),
#   (('British', True), True),
#   (('government', True), True),
#   (('retained', True), True),
#   (('the', True), True),
#   (('single', True), True),
#   (('golden', True), True),
#   (('share', True), True)],
#  [(('He', False), False),
#   (('said', False), False),
#   (('he', False), False),
#   (('was', False), False),
#   (('giving', False), False),
#   (('up', False), False),
#   (('the', False), False),
#   (('golden', False), False),
#   (('share', False), False),
#   (('``', False), False),
#   (('to', True), False),
#   (('clear', True), False),
#   (('the', True), False),
#   (('way', True), False)],
#  [(('Sales', True), True),
#   (('of', True), True),
#   (('new', True), True),
#   (('cars', True), True),
#   (('in', True), True),
#   (('Europe', True), True),
#   (('fell', True), True),
#   (('4.2', True), True),
#   (('%', True), True),
#   (('in', True), True),
#   (('September', True), True),
#   (('from', True), True),
#   (('a', True), True),
#   (('year', True), True),
#   (('earlier', True), True)],
#  [(('London', True), False),
#   (('shares', True), False),
#   (('also', True), False),
#   (('rose', True), False),
#   ((',', False), False)],
#  [(('Advancing', True), True),
#   (('issues', True), True),
#   (('outnumbered', True), True),
#   (('decliners', True), True),
#   (('542', True), True),
#   (('to', True), True),
#   (('362', True), True),
#   ((',', False), True)],
#  [(('First', True), True),
#   ((',', False), False),
#   (('he', False), False),
#   (('said', False), False),
#   ((',', False), False),
#   (('domestic', True), False),
#   (('interest', True), False),
#   (('rates', True), False),
#   (('are', True), False),
#   (('likely', True), False),
#   (('to', True), False),
#   (('stay', True), False),
#   (('at', True), False),
#   (('higher', True), False),
#   (('levels', True), False)],
#  [(('Third', True), True),
#   ((',', True), False),
#   (('oil', True), False),
#   (('prices', True), False),
#   (('have', True), False),
#   (("n't", True), False),
#   (('declined', True), False)],
#  [(('But', True), False),
#   (('trading', True), False),
#   (('was', True), False),
#   (('very', True), False),
#   (('sketchy', True), False),
#   ((',', False), False)],
#  [(('Meanwhile', True), True),
#   ((',', True), False),
#   (('the', True), False),
#   (('broad-based', True), False),
#   (('Financial', True), False),
#   (('Times', True), False),
#   (('100-share', True), False),
#   (('index', True), False),
#   (('added', True), False),
#   (('30.4', True), False),
#   (('points', True), False),
#   (('to', True), False),
#   (('end', True), False),
#   (('at', True), False),
#   (('2142.6', True), False),
#   ((',', False), False)],
#  [(('But', True), False)],
#  [],
#  [(('On', True), True),
#   (('the', True), True),
#   (('Frankfurt', True), True),
#   (('Stock', True), True),
#   (('Exchange', True), True),
#   ((',', True), False),
#   (('share', True), False),
#   (('prices', True), False),
#   (('closed', True), False),
#   (('higher', True), False),
#   (('in', True), False),
#   (('fairly', True), False),
#   (('thin', True), False),
#   (('trading', True), False),
#   ((',', False), False)],
#  [(('As', True), True),
#   (('a', True), True),
#   (('result', True), True),
#   ((',', True), False),
#   (('consumer', True), False),
#   (('prices', True), False),
#   (('for', True), False),
#   (('the', True), False),
#   (('first', True), False),
#   (('10', True), False),
#   (('months', True), False),
#   (('of', True), False),
#   (('1989', True), False),
#   (('surged', True), False),
#   (('by', True), False),
#   (('5', True), False),
#   (('%', True), False)],
#  [(('But', True), False)],
#  [(('I', True), False),
#   (('had', True), False),
#   (('to', True), False),
#   (('reach', True), False),
#   (('back', True), False),
#   (('to', True), False),
#   (('French', True), False),
#   (('101', True), False)],
#  [(('I', True), True),
#   (('was', True), True),
#   (('a', True), True),
#   (('last-minute', True), True),
#   (('-LRB-', True), True),
#   (('read', True), True),
#   (('interloping', True), True),
#   (('-RRB-', True), True),
#   (('attendee', True), True),
#   (('at', True), True),
#   (('a', True), True),
#   (('French', True), True),
#   (('journalism', True), True),
#   (('convention', True), True)],
#  [(('But', True), False)],
#  [(('But', True), False),
#   (('as', True), False),
#   (('the', True), False),
#   (('French', True), False),
#   (('embody', True), False),
#   (('a', True), False),
#   (('Zen-like', True), False),
#   (('state', True), False),
#   (('of', True), False),
#   (('blase', True), False)],
#  [(('They', False), False),
#   (('will', False), False),
#   (('also', False), False),
#   (('tell', False), False),
#   (('you', False), False),
#   (('that', True), False)],
#  [(('They', False), False),
#   (('will', False), False),
#   (('also', False), False),
#   (('tell', False), False),
#   (('you', False), False),
#   (('that', False), False),
#   (('even', True), False),
#   (('if', True), False),
#   (('you', True), False),
#   (('hate', True), False),
#   (('heights', True), False),
#   ((',', False), False),
#   (('you', False), False),
#   (('can', False), False)],
#  [(('In', True), True),
#   (('between', True), True),
#   (('came', True), True),
#   (('lots', True), True),
#   (('of', True), True),
#   (('coffee', True), True),
#   (('drinking', True), True)],
#  [],
#  [(('After', False), True),
#   (('long', False), True),
#   (('stretches', False), True),
#   (('of', False), True),
#   (('this', False), True),
#   (('attendant', False), True),
#   (('ground', False), True),
#   (('activity', False), True),
#   (('came', False), True),
#   (('20', False), True),
#   (('or', False), True),
#   (('so', False), True),
#   (('lovely', False), True),
#   (('minutes', False), True),
#   (('of', False), True),
#   (('drifting', False), True),
#   (('above', False), True),
#   (('the', False), True),
#   (('Vosges', False), True),
#   (('watching', False), True),
#   (('the', True), True),
#   (('silver', True), True),
#   (('mists', True), True),
#   (('rise', True), True),
#   (('off', True), True),
#   (('the', True), True),
#   (('river', True), True)],
#  [(('It', True), False),
#   (("'s", True), False),
#   (('hard', True), False),
#   (('not', True), False),
#   (('to', True), False),
#   (('feel', True), False),
#   (('that', True), False),
#   (('God', True), False),
#   (("'s", True), False),
#   (('in', True), False),
#   (('his', True), False),
#   (('heaven', True), False),
#   (('with', True), False),
#   (('this', True), False),
#   (('kind', True), False),
#   (('of', True), False),
#   (("bird's-eye", True), False),
#   (('view', True), False),
#   (('of', True), False),
#   (('the', True), False),
#   (('world', True), False),
#   ((',', False), False)],
#  [(('Most', True), True),
#   (('balloonists', True), True),
#   (('seldom', True), True),
#   (('go', True), True),
#   (('higher', True), True),
#   (('than', True), True),
#   (('2,000', True), True),
#   (('feet', True), True)],
#  [],
#  [],
#  [(('``', False), False),
#   (('Attention', True), False),
#   ((',', True), False),
#   (("''", True), False),
#   (('yelled', True), False),
#   (('our', True), False),
#   (('pilot', True), False)],
#  [(('We', True), False),
#   (('scuttled', True), False),
#   (('along', True), False),
#   (('for', True), False),
#   (('a', True), False),
#   (('few', True), False),
#   (('feet', True), False)],
#  [(('Eventually', False), True),
#   (('we', False), True),
#   (('came', False), True),
#   (('to', False), True),
#   (('rest', False), True),
#   (('in', False), True),
#   (('a', False), True),
#   (('soggy', False), True),
#   (('patch', False), True),
#   (('of', False), True),
#   (('field', False), True),
#   (('where', True), True),
#   (('we', True), True),
#   (('had', True), True),
#   (('the', True), True),
#   (('exquisite', True), True),
#   (('pleasure', True), True),
#   (('of', True), True),
#   (('scrambling', True), True),
#   (('out', True), True),
#   (('of', True), True),
#   (('the', True), True),
#   (('basket', True), True),
#   (('into', True), True),
#   (('the', True), True),
#   (('mud', True), True)],
#  [(('It', True), True),
#   (('was', True), True),
#   (('the', True), True),
#   (('most', True), True),
#   (('exercise', True), True),
#   (('we', True), True),
#   (("'d", True), True),
#   (('had', True), True),
#   (('all', True), True),
#   (('morning', True), True)],
#  [(('This', False), False),
#   (('meant', False), False),
#   (('returning', False), False),
#   (('to', False), False),
#   (('the', False), False),
#   (('golf', False), False),
#   (('course', False), False),
#   ((',', False), False),
#   (('where', True), False),
#   (('we', True), False),
#   (('watched', True), False),
#   (('a', True), False),
#   (('few', True), False),
#   (('French', True), False),
#   (('duffers', True), False),
#   (('maul', True), False),
#   (('the', True), False),
#   (('first', True), False),
#   (('tee', True), False)],
#  [],
#  [(('Testifying', False), False),
#   (('before', False), False),
#   (('a', False), False),
#   (('House', False), False),
#   (('subcommittee', False), False),
#   ((',', False), False),
#   (('Mr.', False), False),
#   (('Mulford', False), False),
#   (('said', False), False),
#   (('that', True), False)],
#  [(('Rep.', False), False),
#   (('John', False), False),
#   (('LaFalce', False), False),
#   (('-LRB-', False), False),
#   (('D.', False), False),
#   ((',', False), False),
#   (('N.Y', False), False),
#   (('.', False), False),
#   (('-RRB-', False), False),
#   (('said', False), False),
#   (('Mr.', False), False),
#   (('Johnson', False), False),
#   (('refused', False), False),
#   (('to', True), False),
#   (('testify', True), False),
#   (('jointly', True), False),
#   (('with', True), False),
#   (('Mr.', True), False),
#   (('Mulford', True), False),
#   (('and', False), False)],
#  [(('Rep.', False), False),
#   (('John', False), False),
#   (('LaFalce', False), False),
#   (('-LRB-', False), False),
#   (('D.', False), False),
#   ((',', False), False),
#   (('N.Y', False), False),
#   (('.', False), False),
#   (('-RRB-', False), False),
#   (('said', False), False),
#   (('Mr.', False), False),
#   (('Johnson', False), False),
#   (('refused', False), False),
#   (('to', False), False),
#   (('testify', False), False),
#   (('jointly', False), False),
#   (('with', False), False),
#   (('Mr.', False), False),
#   (('Mulford', False), False),
#   (('and', False), False),
#   (('instead', False), False),
#   (('asked', False), False),
#   (('to', True), False),
#   (('appear', True), False)],
#  [(('But', True), False)],
#  [(('In', True), True),
#   (('the', True), True),
#   (('past', True), True),
#   (('year', True), True),
#   ((',', True), False),
#   (('one', True), False),
#   (('inside', True), False),
#   (('director', True), False),
#   (('resigned', True), False),
#   ((',', False), False)],
#  [(('For', False), False),
#   (('one', False), False),
#   (('thing', False), False),
#   ((',', False), False),
#   (('Pentagon', False), False),
#   (('officials', False), False),
#   ((',', False), False),
#   (('who', False), False),
#   (('asked', False), False),
#   (('not', False), False),
#   (('to', False), False),
#   (('be', False), False),
#   (('identified', False), False),
#   ((',', False), False),
#   (('worry', False), False),
#   (('that', False), False),
#   (('the', False), False),
#   (('U.S.', False), False),
#   (('will', False), False),
#   (('have', False), False),
#   (('a', False), False),
#   (('much', False), False),
#   (('tougher', False), False),
#   (('time', False), False),
#   (('persuading', False), False),
#   (('Europeans', False), False),
#   (('to', True), False),
#   (('keep', True), False),
#   (('some', True), False),
#   (('short-range', True), False),
#   (('nuclear', True), False),
#   (('weapons', True), False),
#   (('on', True), False),
#   (('their', True), False),
#   (('soil', True), False)],
#  [(('At', False), False),
#   (('the', False), False),
#   (('same', False), False),
#   (('time', False), False),
#   ((',', False), False),
#   (('they', False), False),
#   (('contend', False), False),
#   (('that', True), False),
#   (('a', True), False),
#   (('reduction', True), False),
#   (('of', True), False),
#   (('NATO', True), False),
#   (('forces', True), False),
#   (('under', True), False),
#   (('a', True), False),
#   (('treaty', True), False),
#   (('will', True), False),
#   (('increase', True), False),
#   (('the', True), False),
#   (('possibility', True), False),
#   (('of', True), False),
#   (('a', True), False),
#   (('conventional', True), False),
#   (('Soviet', True), False),
#   (('attack', True), False)],
#  [(('But', False), False)],
#  [(('Oleg', False), False),
#   (('A.', False), False),
#   (('Grinevsky', False), False),
#   ((',', False), False),
#   (('the', False), False),
#   (('chief', False), False),
#   (('Soviet', False), False),
#   (('negotiator', False), False),
#   (('in', False), False),
#   (('the', False), False),
#   (('conventional-arms', False), False),
#   (('talks', False), False),
#   ((',', False), False),
#   (('argued', False), False),
#   (('that', False), False),
#   (('this', False), False),
#   (('would', False), False),
#   (('mean', False), False),
#   (('the', True), False),
#   (('Soviets', True), False),
#   (('would', True), False),
#   (('have', True), False),
#   (('to', True), False),
#   (('destroy', True), False),
#   (('some', True), False),
#   (('1,800', True), False),
#   (('tanks', True), False),
#   ((',', False), False)],
#  [(('Oleg', False), False),
#   (('A.', False), False),
#   (('Grinevsky', False), False),
#   ((',', False), False),
#   (('the', False), False),
#   (('chief', False), False),
#   (('Soviet', False), False),
#   (('negotiator', False), False),
#   (('in', False), False),
#   (('the', False), False),
#   (('conventional-arms', False), False),
#   (('talks', False), False),
#   ((',', False), False),
#   (('argued', False), False),
#   (('that', False), False),
#   (('this', False), False),
#   (('would', False), False),
#   (('mean', False), False),
#   (('the', False), False),
#   (('Soviets', False), False),
#   (('would', False), False),
#   (('have', False), False),
#   (('to', False), False),
#   (('destroy', False), False),
#   (('some', False), False),
#   (('1,800', False), False),
#   (('tanks', False), False),
#   ((',', False), False),
#   (('while', True), False),
#   (('the', True), False),
#   (('U.S.', True), False),
#   (('would', True), False),
#   (('lose', True), False),
#   (('none', True), False)],
#  [(('The', True), False),
#   (('Soviets', True), False),
#   (('insisted', True), False),
#   (('that', True), False),
#   (('aircraft', True), False),
#   (('be', True), False),
#   (('brought', True), False),
#   (('into', True), False),
#   (('the', True), False),
#   (('talks', True), False),
#   ((',', False), False)],
#  [(('The', False), False),
#   (('Soviets', False), False),
#   (('insisted', False), False),
#   (('that', False), False),
#   (('aircraft', False), False),
#   (('be', False), False),
#   (('brought', False), False),
#   (('into', False), False),
#   (('the', False), False),
#   (('talks', False), False),
#   ((',', False), False),
#   (('then', False), False),
#   (('argued', False), False),
#   (('for', True), False),
#   (('exempting', True), False),
#   (('some', True), False),
#   (('4,000', True), False),
#   (('Russian', True), False),
#   (('planes', True), False)],
#  [(('The', True), True),
#   (('dispute', True), True),
#   (('over', True), True),
#   (('that', True), True),
#   (('issue', True), True),
#   ((',', True), False),
#   (('according', True), False),
#   (('to', True), False),
#   (('one', True), False),
#   (('U.S.', True), False),
#   (('official', True), False),
#   ((',', True), False),
#   (('is', True), False),
#   (('a', True), False),
#   (('``', True), False),
#   (('potential', True), False),
#   (('treaty', True), False),
#   (('stopper', True), False),
#   ((',', False), False),
#   (("''", False), False)],
#  [(('``', False), False), (('So', True), False), (('what', True), False)],
#  [(('``', False), False),
#   (('The', False), False),
#   (('bottom', False), False),
#   (('line', False), False),
#   (('is', False), False),
#   (('that', True), False)],
#  [(('That', True), False), (("'s", True), False)],
#  [(('That', False), False),
#   (("'s", False), False),
#   (('because', True), False)],
#  [(('A', False), False),
#   (('Coca-Cola', False), False),
#   (('spokesman', False), False),
#   (('said', False), False),
#   (('it', False), False),
#   (('is', False), False),
#   (('too', False), False),
#   (('early', False), False),
#   (('to', False), False),
#   (('say', False), False),
#   (('how', True), False),
#   (('the', True), False),
#   (('joint', True), False),
#   (('venture', True), False),
#   (('would', True), False),
#   (('be', True), False),
#   (('structured', True), False),
#   ((',', False), False)],
#  [(('Coke', True), False),
#   (('has', True), False),
#   (('tended', True), False),
#   (('to', True), False),
#   (('increase', True), False),
#   (('its', True), False),
#   (('control', True), False)],
#  [(('Giovanni', True), True),
#   (('Agnelli', True), True),
#   ((',', True), True),
#   (('a', True), True),
#   (('limited', True), True),
#   (('partnership', True), True),
#   (('that', True), True),
#   (('is', True), True),
#   (('the', True), True),
#   (('master', True), True),
#   (('holding', True), True),
#   (('company', True), True),
#   (('for', True), True),
#   (('Fiat', True), True),
#   (("'s", True), True),
#   (('Agnelli', True), True),
#   (('family', True), True),
#   ((',', True), True),
#   (('owns', True), True),
#   (('approximately', True), True),
#   (('75', True), True),
#   (('%', True), True),
#   (('of', True), True),
#   (('the', True), True),
#   (('shares', True), True),
#   (('in', True), True),
#   (('Istituto', True), True),
#   (('Finanziario', True), True),
#   (('Industriale', True), True),
#   ((',', False), True),
#   (('which', False), True)],
#  [(('The', True), False),
#   (('Aga', True), False),
#   (('Khan', True), False),
#   (('owns', True), False),
#   (('10', True), False),
#   (('%', True), False),
#   (('of', True), False),
#   (('Ifint', True), False),
#   (("'s", True), False),
#   (('capital', True), False),
#   ((',', False), False)],
#  [(('The', True), True),
#   (('value', True), True),
#   (('of', True), True),
#   (('the', True), True),
#   (('two', True), True),
#   (('transactions', True), True),
#   (('was', True), True),
#   (("n't", True), True),
#   (('disclosed', True), True),
#   ((',', False), False)],
#  [(('Mr.', True), False),
#   (('Agnelli', True), False),
#   (('and', True), False),
#   (('the', True), False),
#   (('Aga', True), False),
#   (('Khan', True), False),
#   (('also', True), False),
#   (('have', True), False),
#   (('some', True), False),
#   (('business', True), False),
#   (('ties', True), False),
#   ((',', False), False)],
#  [(('Employers', True), False),
#   (('could', True), False),
#   (('also', True), False),
#   (('pay', True), False),
#   (('a', True), False),
#   (('subminimum', True), False),
#   (('``', True), False),
#   (('training', True), False),
#   (('wage', True), False),
#   (("''", True), False),
#   (('for', True), False),
#   (('90', True), False),
#   (('days', True), False),
#   (('to', True), False),
#   (('new', True), False),
#   (('workers', True), False),
#   (('who', True), False),
#   (('are', True), False),
#   (('up', True), False),
#   (('to', True), False),
#   (('19', True), False),
#   (('years', True), False),
#   (('old', True), False),
#   ((',', False), False),
#   (('and', False), False)],
#  [(('Employers', False), False),
#   (('could', False), False),
#   (('also', False), False),
#   (('pay', False), False),
#   (('a', False), False),
#   (('subminimum', False), False),
#   (('``', False), False),
#   (('training', False), False),
#   (('wage', False), False),
#   (("''", False), False),
#   (('for', False), False),
#   (('90', False), False),
#   (('days', False), False),
#   (('to', False), False),
#   (('new', False), False),
#   (('workers', False), False),
#   (('who', False), False),
#   (('are', False), False),
#   (('up', False), False),
#   (('to', False), False),
#   (('19', False), False),
#   (('years', False), False),
#   (('old', False), False),
#   ((',', False), False),
#   (('and', True), False),
#   (('then', True), False),
#   (('for', True), False),
#   (('another', True), False),
#   (('90', True), False),
#   (('days', True), False)],
#  [(('White', False), False),
#   (('House', False), False),
#   (('aides', False), False),
#   (('said', False), False),
#   (('that', True), False)],
#  [(('Under', True), True),
#   (('the', True), True),
#   (('compromise', True), True),
#   ((',', True), False),
#   (('the', True), False),
#   (('$', True), False),
#   (('4.25', True), False),
#   (('level', True), False),
#   (('would', True), False),
#   (('be', True), False),
#   (('reached', True), False),
#   (('nine', True), False),
#   (('months', True), False),
#   (('earlier', True), False),
#   ((',', False), False)],
#  [(('Under', False), False),
#   (('the', False), False),
#   (('compromise', False), False),
#   ((',', False), False),
#   (('the', False), False),
#   (('$', False), False),
#   (('4.25', False), False),
#   (('level', False), False),
#   (('would', False), False),
#   (('be', False), False),
#   (('reached', False), False),
#   (('nine', False), False),
#   (('months', False), False),
#   (('earlier', False), False),
#   ((',', False), False),
#   (('while', True), False),
#   (('the', True), False),
#   (('training', True), False),
#   (('subminimum', True), False),
#   (('would', True), False),
#   (('be', True), False),
#   (('shorter', True), False),
#   ((',', False), False)],
#  [(('Democrats', False), False),
#   (('argued', False), False),
#   (('that', True), False),
#   (('the', True), False),
#   (('training', True), False),
#   (('wage', True), False),
#   (('was', True), False),
#   (('a', True), False),
#   (('way', True), False),
#   (('of', True), False),
#   (('allowing', True), False),
#   (('employers', True), False),
#   (('to', True), False),
#   (('pay', True), False),
#   (('less', True), False),
#   (('than', True), False),
#   (('the', True), False),
#   (('minimum', True), False),
#   (('wage', True), False),
#   ((',', False), False)],
#  [(('In', True), True),
#   (('the', True), True),
#   (('Senate', True), True),
#   ((',', True), False),
#   (('Edward', True), False),
#   (('Kennedy', True), False),
#   (('-LRB-', True), False),
#   (('D.', True), False),
#   ((',', True), False),
#   (('Mass.', True), False),
#   (('-RRB-', True), False),
#   ((',', True), False),
#   (('chairman', True), False),
#   (('of', True), False),
#   (('the', True), False),
#   (('Labor', True), False),
#   (('Committee', True), False),
#   ((',', True), False),
#   (('and', True), False),
#   (('Pete', True), False),
#   (('Domenici', True), False),
#   ((',', True), False),
#   (('-LRB-', True), False),
#   (('R.', True), False),
#   ((',', True), False),
# ...
#   (('drafted', True), False),
#   (('could', True), False),
#   (('put', True), False),
#   (('companies', True), False),
#   (('in', True), False),
#   (('violation', True), False),
#   (('of', True), False),
#   (('the', True), False),
#   (('tax', True), False),
#   (('code', True), False)],
#  [(('The', False), False),
#   (('IRS', False), False),
#   (('says', False), False),
#   (('the', True), False),
#   (('question', True), False),
#   (('wo', True), False),
#   (("n't", True), False),
#   (('be', True), False),
#   (('settled', True), False)],
#  [(('Employees', True), True),
#   (('like', True), True),
#   (('the', True), True),
#   (('option', True), True)],
#  [(('Still', True), True),
#   ((',', True), False),
#   (('the', True), False),
#   (('school', True), False),
#   (('says', True), False),
#   (('there', True), False),
#   (('are', True), False),
#   (('an', True), False),
#   (('ample', True), False),
#   (('number', True), False)],
#  [(('But', True), False)],
#  [(('Two', True), True),
#   (('left-wing', True), True),
#   (('politicians', True), True),
#   ((',', True), True),
#   (('Socialist', True), True),
#   (('Leonel', True), True),
#   (('Brizola', True), True),
#   ((',', True), True),
#   (('a', True), True),
#   (('former', True), True),
#   (('governor', True), True),
#   (('of', True), True),
#   (('Rio', True), True),
#   (('de', True), True),
#   (('Janeiro', True), True),
#   (('state', True), True),
#   ((',', True), True),
#   (('and', True), True),
#   (('Marxist-leaning', True), True),
#   (('Luis', True), True),
#   (('Inacio', True), True),
#   (('da', True), True),
#   (('Silva', True), True),
#   ((',', True), True),
#   (('currently', True), True),
#   (('are', True), True),
#   (('running', True), True),
#   (('neck', True), True),
#   (('and', True), True),
#   (('neck', True), True),
#   (('at', True), True),
#   (('about', True), True),
#   (('15', True), True),
#   (('%', True), True),
#   ((',', False), True)],
#  [],
#  [(('If', False), True),
#   (('Brazil', False), True),
#   (('devises', False), True),
#   (('an', False), True),
#   (('economic', False), True),
#   (('strategy', False), True),
#   (('allowing', False), True),
#   (('it', False), True),
#   (('to', False), True),
#   (('resume', False), True),
#   (('growth', False), True),
#   (('and', False), True),
#   (('service', False), True),
#   (('debt', False), True),
#   ((',', False), False),
#   (('this', False), False),
#   (('could', False), False),
#   (('lead', False), False),
#   (('it', False), False),
#   (('to', False), False),
#   (('open', False), False),
#   (('up', False), False),
#   (('and', False), False),
#   (('deregulate', False), False),
#   (('its', False), False),
#   (('sheltered', False), False),
#   (('economy', False), False),
#   ((',', False), False),
#   (('analysts', False), False),
#   (('say', False), False),
#   ((',', False), False),
#   (('just', True), False),
#   (('as', True), False),
#   (('Argentinian', True), False),
#   (('President', True), False),
#   (('Carlos', True), False),
#   (('Saul', True), False),
#   (('Menem', True), False),
#   (('has', True), False),
#   (('been', True), False),
#   (('doing', True), False)],
#  [(('That', True), True),
#   (('might', True), True),
#   (('have', True), True),
#   (('been', True), True),
#   (('considered', True), True),
#   (('hyperinflation', True), True),
#   (('not', True), True),
#   (('long', True), True),
#   (('ago', True), True),
#   ((',', False), False)],
#  [(('That', False), False),
#   (('might', False), False),
#   (('have', False), False),
#   (('been', False), False),
#   (('considered', False), False),
#   (('hyperinflation', False), False),
#   (('not', False), False),
#   (('long', False), False),
#   (('ago', False), False),
#   ((',', False), False),
#   (('but', True), False),
#   (('Argentina', True), False),
#   (('endured', True), False),
#   (('price', True), False),
#   (('increases', True), False),
#   (('of', True), False),
#   (('almost', True), False),
#   (('200', True), False),
#   (('%', True), False),
#   (('in', True), False),
#   (('July', True), False)],
#  [(('It', False), False),
#   (("'s", False), False),
#   (('not', False), False),
#   (('uncommon', False), False),
#   (('to', True), False),
#   (('wait', True), False),
#   (('three', True), False),
#   (('minutes', True), False),
#   (('for', True), False),
#   (('a', True), False),
#   (('dial', True), False),
#   (('tone', True), False)],
#  [(('It', False), False),
#   (("'s", False), False),
#   (('not', False), False),
#   (('uncommon', False), False),
#   (('to', True), False),
#   (('wait', True), False),
#   (('three', True), False),
#   (('minutes', True), False),
#   (('for', True), False),
#   (('a', True), False),
#   (('dial', True), False),
#   (('tone', True), False),
#   (('after', True), False),
#   (('picking', True), False),
#   (('up', True), False),
#   (('the', True), False),
#   (('telephone', True), False),
#   ((',', False), False),
#   (('and', False), False)],
#  [(('It', False), False),
#   (("'s", False), False),
#   (('not', False), False),
#   (('uncommon', False), False),
#   (('to', False), False),
#   (('wait', False), False),
#   (('three', False), False),
#   (('minutes', False), False),
#   (('for', False), False),
#   (('a', False), False),
#   (('dial', False), False),
#   (('tone', False), False),
#   (('after', False), False),
#   (('picking', False), False),
#   (('up', False), False),
#   (('the', False), False),
#   (('telephone', False), False),
#   ((',', False), False),
#   (('and', True), False),
#   (('then', True), False),
#   (('to', True), False),
#   (('be', True), False),
#   (('interrupted', True), False),
#   (('by', True), False),
#   (('a', True), False),
#   (('busy', True), False),
#   (('signal', True), False)],
#  [(('The', True), True),
#   (('67-year-old', True), True),
#   (('Mr.', True), True),
#   (('Brizola', True), True),
#   (('has', True), True),
#   (('been', True), True),
#   (('vague', True), True),
#   (('about', True), True),
#   (('his', True), True),
#   (('intentions', True), True),
#   (('and', True), True),
#   (('often', True), True),
#   (('inflammatory', True), True),
#   (('in', True), True),
#   (('his', True), True),
#   (('rhetoric', True), True),
#   ((',', False), False)],
#  [],
#  [(('But', False), False),
#   (('Humana', False), False),
#   (('says', False), False),
#   (('its', True), False),
#   (('own', True), False),
#   (('facilities', True), False),
#   (('could', True), False),
#   (('serve', True), False),
#   (('its', True), False),
#   (('insured', True), False),
#   (('for', True), False),
#   (('less', True), False)],
#  [],
#  [(('Humana', False), False),
#   (('contends', False), False),
#   (('that', True), False),
#   (('$', True), False),
#   (('8,000', True), False),
#   (('represents', True), False),
#   (('an', True), False),
#   (('extreme', True), False),
#   (('case', True), False)],
#  [(('And', True), False),
#   (('81', True), False),
#   (('%', True), False),
#   (('preferred', True), False),
#   (('a', True), False),
#   (('group', True), False),
#   (('practice', True), False),
#   (('or', True), False),
#   (('health', True), False),
#   (('maintenance', True), False),
#   (('organization', True), False),
#   ((',', False), False)],
#  [],
#  [(('``', False), False),
#   (('It', True), False),
#   (('helps', True), False),
#   (('us', True), False),
#   ((',', True), False),
#   (('and', True), False),
#   (('them', True), False),
#   ((',', False), False)],
#  [(('``', False), False),
#   (('It', True), False),
#   (('helps', True), False),
#   (('us', True), False),
#   ((',', True), False),
#   (('and', True), False),
#   (('them', True), False),
#   ((',', True), False),
#   (('while', True), False),
#   (('they', True), False),
#   (("'re", True), False),
#   (('here', True), False),
#   ((',', False), False)],
#  [(('``', False), False),
#   (('It', False), False),
#   (('helps', False), False),
#   (('us', False), False),
#   ((',', False), False),
#   (('and', False), False),
#   (('them', False), False),
#   ((',', False), False),
#   (('while', False), False),
#   (('they', False), False),
#   (("'re", False), False),
#   (('here', False), False),
#   ((',', False), False),
#   (('and', True), False),
#   (('it', True), False),
#   (('certainly', True), False),
#   (('makes', True), False),
#   (('them', True), False),
#   (('a', True), False),
#   (('better', True), False),
#   (('health-care', True), False),
#   (('team', True), False)],
#  [],
#  [(('Indeed', False), False),
#   ((',', False), False),
#   (('some', False), False),
#   (('individuals', False), False),
#   (('identified', False), False),
#   (('with', False), False),
#   (('the', False), False),
#   (('group', False), False),
#   (('said', False), False),
#   (('they', False), False),
#   (('have', False), False),
#   (("n't", False), False),
#   (('committed', False), False),
#   (('any', False), False),
#   (('money', False), False),
#   (('to', False), False),
#   (('the', False), False),
#   (('bid', False), False),
#   (('and', True), False),
#   (('were', True), False),
#   (("n't", True), False),
#   (('aware', True), False),
#   (('of', True), False),
#   (('it', True), False)],
#  [(('But', False), False),
#   (('in', False), False),
#   (('an', False), False),
#   (('interview', False), False),
#   ((',', False), False),
#   (('Mr.', False), False),
#   (('McMaster', False), False),
#   (('said', False), False),
#   (('he', True), False),
#   (('and', True), False),
#   (('his', True), False),
#   (('investment', True), False),
#   (('banker', True), False),
#   (('would', True), False),
#   (('need', True), False),
#   (('access', True), False),
#   (('to', True), False),
#   (('full', True), False),
#   (('financial', True), False),
#   (('records', True), False)],
#  [(('The', False), True),
#   (('partnership', False), True),
#   (('said', False), True),
#   (('it', True), True),
#   (('is', True), True),
#   (('proposing', True), True),
#   (('the', True), True),
#   (('change', True), True)],
#  [(('After', True), True),
#   (('the', True), True),
#   (('transaction', True), True),
#   ((',', True), False),
#   (('current', True), False),
#   (('common', True), False),
#   (('unitholders', True), False),
#   (('will', True), False),
#   (('own', True), False),
#   (('about', True), False),
#   (('21.3', True), False),
#   (('%', True), False),
#   (('of', True), False),
#   (('Edisto', True), False),
#   ((',', True), False),
#   (('current', True), False),
#   (('acquisition', True), False),
#   (('preferred', True), False),
#   (('holders', True), False),
#   (('will', True), False),
#   (('own', True), False),
#   (('72.3', True), False),
#   (('%', True), False),
#   ((',', False), False)],
#  [(('Cleveland-based', True), True),
#   (('Sherwin-Williams', True), True),
#   (('produces', True), True),
#   (('paints', True), True),
#   (('and', True), True),
#   (('coatings', True), True),
#   ((',', False), True)],
#  [(('USG', False), False),
#   (('Corp.', False), False),
#   (('agreed', False), False),
#   (('to', False), False),
#   (('sell', False), False),
#   (('its', False), False),
#   (('headquarters', False), False),
#   (('building', False), False),
#   (('here', False), False),
#   (('to', False), False),
#   (('Manufacturers', False), False),
#   (('Life', False), False),
#   (('Insurance', False), False),
#   (('Co.', False), False),
#   (('of', False), False),
#   (('Toronto', False), False),
#   ((',', False), False),
#   (('and', True), False),
#   (('will', True), False),
#   (('lease', True), False),
#   (('the', True), False),
#   (('19-story', True), False),
#   (('facility', True), False)],
#  [],
#  [(('``', False), False),
#   (('Confidence', True), False),
#   (('was', True), False),
#   (('starting', True), False),
#   (('to', True), False),
#   (('come', True), False),
#   (('back', True), False)],
#  [(('But', True), False)],
#  [(('``', False), False)],
#  [],
#  [(('Dark', False), False),
#   (('hints', False), False),
#   (('would', False), False),
#   (('be', False), False),
#   (('raised', False), False),
#   (('that', False), False),
#   (('parts', False), False),
#   (('of', False), False),
#   (('the', False), False),
#   (('administration', False), False),
#   (('hope', False), False),
#   (('Mr.', False), False),
#   (('Gorbachev', False), False),
#   (('would', False), False),
#   (('fail', False), False),
#   ((',', False), False),
#   (('just', True), False),
#   (('as', True), False),
#   (('they', True), False),
#   (('were', True), False)],
#  [(('Perhaps', False), False),
#   (('Mr.', False), False),
#   (('Gates', False), False),
#   (('would', False), False),
#   (('emphasize', False), False),
#   (('more', False), False),
#   (('than', False), False),
#   (('Mr.', False), False),
#   (('Baker', False), False),
#   (('the', False), False),
#   (('many', False), False),
#   (('hurdles', False), False),
#   (('the', True), False),
#   (('Soviet', True), False),
#   (('leader', True), False),
#   (('must', True), False),
#   (('leap', True), False)],
#  [(('GATT', True), True),
#   (('membership', True), True),
#   (('will', True), True),
#   (('not', True), True),
#   (('matter', True), True),
#   (('to', True), True),
#   (('Donbas', True), True),
#   (('coal', True), True),
#   (('miners', True), True),
#   (('short', True), True),
#   (('of', True), True),
#   (('soap', True), True),
#   ((',', False), True)],
#  [],
#  [(('We', True), True),
#   (('do', True), True),
#   (("n't", True), True),
#   (('expect', True), True),
#   (('much', True), True),
#   (('good', True), True),
#   (('from', True), True),
#   (('nuclear-arms', True), True),
#   (('control', True), True),
#   ((',', False), False)],
#  [(('There', True), True),
#   (("'s", True), True),
#   (('nothing', True), True),
#   (('in', True), True),
#   (('the', True), True),
#   (('least', True), True),
#   (('contradictory', True), True),
#   (('in', True), True),
#   (('all', True), True),
#   (('this', True), True),
#   ((',', False), False)],
#  [(('So', True), True),
#   (('every', True), True),
#   (('time', True), True),
#   (('a', True), True),
#   (('Bush', True), True),
#   (('official', True), True),
#   (('raises', True), True),
#   (('a', True), True),
#   (('doubt', True), True),
#   (('about', True), True),
#   (('Mr.', True), True),
#   (('Gorbachev', True), True),
#   ((',', True), False),
#   (('the', True), False),
#   (('Washington', True), False),
#   (('community', True), False),
#   (('shouts', True), False),
#   (('``', True), False),
#   (('Cold', True), False),
#   (('War', True), False),
#   (("''", True), False),
#   (('and', True), False),
#   (('``', True), False),
#   (('timidity', True), False),
#   ((',', False), False),
#   (("''", False), False)],
#  [(('In', True), True),
#   (('short', True), True),
#   ((',', True), False),
#   (('the', True), False),
#   (('problem', True), False),
#   (('is', True), False),
#   (('not', True), False),
#   (('intra-administration', True), False),
#   (('disagreement', True), False),
#   ((',', True), False),
#   (('but', True), False),
#   (('preoccupation', True), False),
#   (('with', True), False),
#   (('the', True), False),
#   (('prospect', True), False),
#   (('that', True), False),
#   (('perestrokia', True), False),
#   (('might', True), False),
#   (('fail', True), False),
#   ((',', False), False)],
#  [(('Mr.', True), True),
#   (('Baker', True), True),
#   (('may', True), True),
#   (('want', True), True),
#   (('to', True), True),
#   (('avoid', True), True),
#   (('criticism', True), True),
#   (('from', True), True),
#   (('Senate', True), True),
#   (('Majority', True), True),
#   (('Leader', True), True),
#   (('George', True), True),
#   (('Mitchell', True), True),
#   ((',', False), False)],
#  [],
#  [(('Most', True), True),
#   (('murders', True), True),
#   (('are', True), True),
#   (('state', True), True),
#   (('crimes', True), True),
#   ((',', False), False)],
#  [(('Senate', True), False),
#   (('Republicans', True), False),
#   ((',', False), False)],
#  [(('But', False), False),
#   (('in', False), False),
#   (('1976', False), False),
#   ((',', False), False),
#   (('the', False), False),
#   (('court', False), False),
#   (('permitted', False), False),
#   (('resurrection', True), False),
#   (('of', True), False),
#   (('such', True), False),
#   (('laws', True), False),
#   ((',', False), False)],
#  [(('For', False), False),
#   (('instance', False), False),
#   ((',', False), False),
#   (('juries', False), False),
#   (('would', False), False),
#   (('have', False), False),
#   (('to', True), False),
#   (('consider', True), False),
#   (('specific', True), False),
#   (('``', True), False),
#   (('aggravating', True), False),
#   (("''", True), False),
#   (('and', True), False),
#   (('``', True), False),
#   (('mitigating', True), False),
#   (("''", True), False),
#   (('factors', True), False)]]
