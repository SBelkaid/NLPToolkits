# %% [markdown]
# # Arg classifier

# %%
import json
import pickle
import nltk
from nltk.tree import Tree
from nltk.tree import ParentedTree
from collections import defaultdict

# %%
with open('conll16st-en-01-12-16-train/relations.json', encoding='utf-8') as pdtb_file:
    relations = [json.loads(x) for x in pdtb_file];
    
with open('conll16st-en-01-12-16-train/parses.json', encoding='utf8') as parse_file:
    parses = json.load(parse_file)

# %%
# We only want explicit relations:

def explicit_relations(relations):
    '''Extract all explicit relations from the relations file'''
    relations_explicit = []

    for relation in relations:
        if relation['Type'] == 'Explicit':
            relations_explicit.append(relation)
    return (relations_explicit)

ex_relations = explicit_relations(relations)

# %%
# Seperate them into PS and SS relations

def ss_ps_relations(explicit_relations):
    '''
    Sort relations into same sentence and previous sentence relations
    '''
    
    relations_ss = []
    relations_ps = []
    #relations_other = []

    for relation in explicit_relations:
        sentence_id_arg1 = relation['Arg1']['TokenList'][0][3]
        sentence_id_connective = relation['Connective']['TokenList'][0][3]
        sentence_id_arg2 = relation['Arg2']['TokenList'][0][3]
    
        if sentence_id_arg1 == sentence_id_connective == sentence_id_arg2:
            relations_ss.append(relation)
        elif int(sentence_id_arg1) == int(sentence_id_connective) - 1 == int(sentence_id_arg2) -1:
            relations_ps.append(relation)
        #else: 
            #relations_other.append(relation)
            
    return relations_ss, relations_ps

ss_relations, ps_relations = ss_ps_relations(ex_relations)

# %%
def get_phrase_structure(docID, sentenceID):
    """
    Retrieve phrase_structure from the parses.json file by filename and sentenceID.
    """
         
    sentencelist = parses[docID]["sentences"]    
    phrase_structure = sentencelist[sentenceID]["parsetree"]
    
    return phrase_structure

# %% [markdown]
# # Output format

# %%
def get_constituent(docID,sentenceID,index,pos,token):
    """
    Finds parent node of input token. 
    """
    
    phrase_structure = get_phrase_structure(docID, sentenceID)    
    tree = Tree.fromstring(phrase_structure)    
    tree = ParentedTree.convert(tree)
    
    for subtree in tree.subtrees(filter=lambda x:
                                 x.label() == pos and x[0] == token):
        return subtree.parent().label()

#get_constituent("wsj_0204",6,0,"DT","The")

# %%
def get_upper_constituent():
    pass

# %%
featuresdict = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))

# %% [markdown]
# ### SS relations

# %%
tuplelist = []
featurelist = []

for relation in ss_relations:
    
    tokenlist = []
    sentencefeatures = []
    
    connective = relation["Connective"]["RawText"]
    connective_index = relation["Connective"]["TokenList"][0][4]
    docID = relation["DocID"]
    
    arg1_tokenlist = relation["Arg1"]["TokenList"]
    arg2_tokenlist = relation["Arg2"]["TokenList"]
    
    #retrieve phrase structure for sentence the argument is in
    arg1_sentenceID = arg1_tokenlist[0][3]
    arg1_phrase_structure = get_phrase_structure(docID, arg1_sentenceID)
    
    arg2_sentenceID = arg2_tokenlist[0][3]
    arg2_phrase_structure = get_phrase_structure(docID, arg2_sentenceID) #should be the same
    
    
    # Build a list with indices of words in the argument
    indices = []
    
    for wordspan in arg1_tokenlist:

        index = wordspan[4]        
        indices.append(index)

        
    # Every word that precedes the connective
    word_data = parses[docID]["sentences"][arg1_sentenceID]["words"][:connective_index]
    
    for index, word in enumerate(word_data):
        
        features = dict()
        
        pos = word[1]["PartOfSpeech"]
        token = word[0]
        
        if index in indices:
            argpart = True
        else:
            argpart = False
        
        constituent = get_constituent(docID,arg1_sentenceID,index,pos,token)
        
        #tokenlist.append(((word[0],argpart),pos,constituent,connective))
        
        
        
        features["pos"] = pos
        features["constituent"] = constituent
#         features["upper_constituent"] = FUNCTION
        
        features["connective"] = connective
        
        sentencefeatures.append(features)
        
        tokenlist.append((word[0], argpart))
        
        featuresdict[docID]["Sentences"][arg1_sentenceID].append({
                "token": word[0],
                "pos": pos,
                "constituent": constituent,
                "connective": connective,
                "label": argpart
            })
  
    
    featurelist.append(sentencefeatures)
    tuplelist.append(tokenlist)

# %%
json.dump(featuresdict, open("features_SS.json", "w", encoding="utf-8"), indent=4)

# %% [markdown]
# ### relations

# %%
def get_features(ps_relations, sentence_type):

    #preparing the format for the json output
    featuresdict_arg1 = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))
    featuresdict_arg2 = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))

    for relation in ps_relations:

        connective = relation["Connective"]["RawText"]
        connective_index = relation["Connective"]["TokenList"][0][4]
        docID = relation["DocID"]

        arg1_tokenlist = relation["Arg1"]["TokenList"]
        arg2_tokenlist = relation["Arg2"]["TokenList"]

        #retrieve phrase structure for sentence the argument is in
        arg1_sentenceID = arg1_tokenlist[0][3]
        arg1_phrase_structure = get_phrase_structure(docID, arg1_sentenceID)

        arg2_sentenceID = arg2_tokenlist[0][3]
        arg2_phrase_structure = get_phrase_structure(docID, arg2_sentenceID)


        # Build a list with indices of words in the argument
        indices = []

        for wordspan in arg1_tokenlist:

            index = wordspan[4]        
            indices.append(index)

        #SENTENCE TYPE
        if sentence_type == "SS":
            # Every word that precedes the connective
            word_data_arg1 = parses[docID]["sentences"][arg1_sentenceID]["words"][:connective_index] 
            
        if sentence_type == "PS":
            # Every word in the sentence 
            word_data_arg1 = parses[docID]["sentences"][arg1_sentenceID]["words"]
            
        word_data_arg2 = parses[docID]["sentences"][arg2_sentenceID]["words"][connective_index:]

        
        for index, word in enumerate(word_data_arg1):
                pos = word[1]["PartOfSpeech"]
                token = word[0]

                if index in indices:
                    argpart = True
                else:
                    argpart = False

                constituent = get_constituent(docID,arg1_sentenceID,index,pos,token)

                featuresdict_arg1[docID]["Sentences"][arg1_sentenceID].append({
                        "token": word[0],
                        "pos": pos,
                        "constituent": constituent,
                        "connective": connective,
                        "label": argpart
                    })
                
        for index, word in enumerate(word_data_arg2):
                pos = word[1]["PartOfSpeech"]
                token = word[0]

                if index in indices:
                    argpart = True
                else:
                    argpart = False

                constituent = get_constituent(docID,arg1_sentenceID,index,pos,token)

                featuresdict_arg2[docID]["Sentences"][arg1_sentenceID].append({
                        "token": word[0],
                        "pos": pos,
                        "constituent": constituent,
                        "connective": connective,
                        "label": argpart
                    })

          
    
    return featuresdict_arg1, featuresdict_arg2

# %%
def wrap(ss_relations, ps_relations):
    featuresdict_ps, featuresdict_ps_arg2 = get_features(ps_relations, "PS")
    print("Got features from PS relations!")
    
    featuresdict_ss, featuresdict_ss_arg2 = get_features(ss_relations, "SS")
    print("Got features from SS relations!")
    
    json.dump(featuresdict_ps, open("features_PS.json", "w", encoding="utf-8"))
    json.dump(featuresdict_ps_arg2, open("features_PS_arg2.json", "w", encoding="utf-8"))
    
    json.dump(featuresdict_ss, open("features_SS.json", "w", encoding="utf-8"))
    json.dump(featuresdict_ss_arg2, open("features_SS_arg2.json", "w", encoding="utf-8"))

# %%
wrap(ss_relations, ps_relations)

# %% [markdown]
# ## Building the Tuplelist

# %%
def tuplebuilder(features_json):
    """
    Makes a tuplelist and corresponding featurelist
    from an inputted features.json file. 
    
    Outputs a tuplelist and a featurelist in a list for every sentence. 
    
    """
    
    with open(features_json, encoding='utf8') as features_file:
        features = json.load(features_file)

    tuplelist = []
    featurelist = []

    for docID in features.keys():
        for sentence_n in features[docID]["Sentences"]:

            #reset content of tokenlist
            tokenlist = []
            sentencetokenfeatures = []

            for token in features[docID]["Sentences"][sentence_n]:
                tokenfeatures = dict()

                #importing variables from tokeninfo
                for feature, value in token.items():
                    if feature != "label":
                        tokenfeatures[feature] = value

                tokenstring = token["token"]
                argpart = token["label"]

                tokentuple = (tokenstring, argpart)    

                tokenlist.append(tokentuple)           
                sentencetokenfeatures.append(tokenfeatures)

            #Building tuple
            tuplelist.append(tokenlist)
            featurelist.append(sentencetokenfeatures)
            
    return tuplelist, featurelist
            
tuplelist, featurelist = tuplebuilder("features.json")

# %% [markdown]
# ## The classifier

# %%
def arg_features(sentence, i, history, n_sent):
    
    features = featurelist[n_sent][i]
    #print(features)
    
    if i == 0:
        features["prev-word"] = "<START>"
        features["prev-tag"] = "<START>"
    else:
        features["prev-word"] = sentence[i-1]
        features["prev-tag"] = history[i-1]
        
#     print(features)
    return features

# %%
class ConsecutiveArgTagger(nltk.TaggerI):

    def __init__(self, train_sents):
        train_set = []
        for n_sent, tagged_sent in enumerate(train_sents):
            untagged_sent = nltk.tag.untag(tagged_sent)
#             print(untagged_sent)
            history = []
            for i, (word, tag) in enumerate(tagged_sent):
                featureset = arg_features(untagged_sent, i, history, n_sent)
                train_set.append( (featureset, tag) )
                history.append(tag)
        self.classifier = nltk.NaiveBayesClassifier.train(train_set)

    def tag(self, sentence):
        
        global count
        
        history = []
#         print(sentence,"\n")
        for i, word in enumerate(sentence):
            featureset = arg_features(sentence, i, history, count)
            tag = self.classifier.classify(featureset)
            history.append(tag)
            
        count += 1 #for the sentenceID
        
        return list(zip(sentence, history))

# %%
tagger = ConsecutiveArgTagger(tuplelist)

# %%
pickle.dump(tagger, open("tagger_SS.pickle", "wb"))

# %% [markdown]
# ### Evaluating

# %%
count = 0 #reset the sentenceID
size = int(len(tuplelist) * 0.1)

# %%
train_sents, test_sents = tuplelist[size:], tuplelist[:size]

# %%
print(tagger.evaluate(test_sents))
# Out:
# 0.6594021376085505

# %%
tagger.tag_sents(test_sents)
# Out:
# [[(('He', False), False),
#   (('said', False), False),
#   (('construction', True), False),
#   (('would', True), False),
#   (("n't", True), False),
#   (('resume', True), False)],
#  [(('Mr.', False), False),
#   (('Maxwell', False), False),
#   (('said', False), False),
#   (('he', True), False),
#   (('would', True), False),
#   (("n't", True), False),
#   (('be', True), False),
#   (('surprised', True), False)],
#  [(('But', True), False),
#   (('the', True), False),
#   (('Memphis', True), False),
#   ((',', True), False),
#   (('Tenn.', True), False),
#   ((',', True), False),
#   (('facility', True), False),
#   (('was', True), False),
#   (("n't", True), False),
#   (('to', True), False),
#   (('begin', True), False),
#   (('turning', True), False),
#   (('out', True), False),
#   (('product', True), False),
#   (('until', True), False),
#   (('1993', True), False),
#   ((',', False), False)],
#  [(('Last', False), True),
#   (('Friday', False), True),
#   (("'s", False), True),
#   (('announcement', False), True),
#   (('was', False), True),
#   (('the', False), True),
#   (('first', False), True),
#   (('official', False), True),
#   (('word', False), True),
#   (('that', True), True),
#   (('the', True), True),
#   (('project', True), True),
#   (('was', True), True),
#   (('in', True), True),
#   (('trouble', True), True)],
#  [(('Kellogg', True), True),
#   (("'s", True), True),
#   (('current', True), True),
#   (('share', True), True),
#   (('is', True), True),
#   (('believed', True), True),
#   (('to', True), True),
#   (('be', True), True),
#   (('slightly', True), True),
#   (('under', True), True),
#   (('40', True), True),
#   (('%', True), True)],
#  [(('``', False), False),
#   (('``', False), False),
#   (('As', True), False),
#   (('we', True), False),
#   (('regain', True), False),
#   (('our', True), False),
#   (('leadership', True), False),
#   (('level', True), False),
#   (('where', True), False),
#   (('we', True), False),
#   (('have', True), False),
#   (('been', True), False),
#   ((',', False), False),
#   (('``', False), False),
#   (('As', False), False),
#   (('we', False), False),
#   (('regain', False), False),
#   (('our', False), False),
#   (('leadership', False), False),
#   (('level', False), False),
#   (('where', False), False),
#   (('we', False), False),
#   (('have', False), False),
#   (('been', False), False),
#   ((',', False), False),
#   (('and', True), False)],
#  [(('``', False), False),
#   (('Cheerios', True), False),
#   (('and', True), False),
#   (('Honey', True), False),
#   (('Nut', True), False),
#   (('Cheerios', True), False),
#   (('have', True), False),
#   (('eaten', True), False),
#   (('away', True), False),
#   (('sales', True), False),
#   (('normally', True), False),
#   (('going', True), False),
#   (('to', True), False),
#   (('Kellogg', True), False),
#   (("'s", True), False),
#   (('corn-based', True), False),
#   (('lines', True), False)],
#  [(('General', True), False),
#   (('Mills', True), False),
#   ((',', True), False),
#   (('meanwhile', True), False),
#   ((',', True), False),
#   (('finds', True), False),
#   (('itself', True), False),
#   (('constrained', True), False),
#   (('from', True), False),
#   (('boosting', True), False),
#   (('sales', True), False),
#   (('further', True), False)],
#  [(('The', True), True),
#   (('California', True), True),
#   (('Democrat', True), True),
#   (('appeared', True), True),
#   (('embarrassed', True), True),
#   (('by', True), True),
#   (('provisions', True), True),
#   (('inserted', True), True),
#   (('on', True), True),
#   (('behalf', True), True),
#   (('of', True), True),
#   (('owners', True), True),
#   (('of', True), True),
#   (('private', True), True),
#   (('beaches', True), True),
#   (('in', True), True),
#   (('the', True), True),
#   (('Virgin', True), True),
#   (('Islands', True), True),
#   ((',', False), False)],
#  [(('By', True), True),
#   (('a', True), True),
#   (('26-7', True), True),
#   (('margin', True), True),
#   ((',', True), False),
#   (('the', True), False),
#   (('committee', True), False),
#   (('scuttled', True), False),
#   (('the', True), False),
#   (('more', True), False),
#   (('expensive', True), False),
#   (('alternative', True), False),
#   ((',', False), False)],
#  [(('A', True), True),
#   (('White', True), True),
#   (('House', True), True),
#   (('budget', True), True),
#   (('office', True), True),
#   (('analysis', True), True),
#   (('estimates', True), True),
#   (('that', True), True),
#   (('$', True), True),
#   (('500', True), True),
#   (('million', True), True),
#   (('--', True), False),
#   (('or', True), False),
#   (('half', True), False),
#   (('the', True), False),
#   (('level', True), False),
#   (('in', True), False),
#   (('the', True), False),
#   (('committee', True), False),
#   (('bill', True), False),
#   (('--', True), False),
#   (('is', True), False),
#   (('needed', True), False),
#   (('for', True), False),
#   (('highway', True), False),
#   (('assistance', True), True),
#   (('to', True), True),
#   (('meet', True), True),
#   (('California', True), True),
#   (("'s", True), True),
#   (('needs', True), True),
#   ((',', False), False)],
#  [(('Mr.', True), False),
#   (('Whitten', True), False),
#   (("'s", True), False),
#   (('package', True), False),
#   (('appears', True), False),
#   (('to', True), False),
#   (('accomplish', True), False),
#   (('this', True), False),
#   (('purpose', True), False),
#   ((',', False), False)],
#  [(('The', True), True),
#   (('measure', True), True),
#   (('is', True), True),
#   (('expected', True), True),
#   (('to', True), True),
#   (('come', True), True),
#   (('before', True), True),
#   (('the', True), True),
#   (('House', True), True),
#   (('today', True), True),
#   ((',', False), False)],
#  [(('``', False), False),
#   (('We', True), False),
#   (('are', True), False),
#   (('the', True), False),
#   (('Golden', True), False),
#   (('State', True), False),
#   ((',', False), False),
#   (("''", False), False),
#   (('Mr.', False), False),
#   (('Fazio', False), False),
#   (('said', False), False),
#   ((',', False), False),
#   (('``', False), False)],
#  [(('On', True), True),
#   (('the', True), True),
#   (('chairman', True), True),
#   (("'s", True), True),
#   (('motion', True), True),
#   ((',', True), False),
#   (('the', True), False),
#   (('California', True), False),
#   (('package', True), False),
#   (('was', True), False),
#   (('subsequently', True), False),
#   (('reduced', True), False),
#   (('to', True), False),
#   (('less-binding', True), False),
#   (('report', True), False),
#   (('language', True), False),
#   ((',', False), False),
#   (('On', False), False),
#   (('the', False), False),
#   (('chairman', False), False),
#   (("'s", False), False),
#   (('motion', False), False),
#   ((',', False), False),
#   (('the', False), False),
#   (('California', False), False),
#   (('package', False), False),
#   (('was', False), False),
#   (('subsequently', False), False),
#   (('reduced', False), False),
#   (('to', False), False),
#   (('less-binding', False), False),
#   (('report', False), False),
#   (('language', False), False),
#   ((',', False), False),
#   (('and', True), False)],
#  [(('The', True), True),
#   (('package', True), True),
#   (('was', True), True),
#   (('termed', True), True),
#   (('excessive', True), True),
#   (('by', True), True),
#   (('the', True), True),
#   (('Bush', True), True),
#   (('administration', True), True),
#   ((',', False), False),
#   (('The', True), False),
#   (('package', True), False),
#   (('was', True), False),
#   (('termed', True), False),
#   (('excessive', True), False),
#   (('by', True), False),
#   (('the', True), False),
#   (('Bush', True), False),
#   (('administration', True), False),
#   ((',', False), False),
#   (('but', False), False),
#   (('it', False), False)],
#  [(('``', False), False),
#   (('I', False), False),
#   (('would', False), False),
#   (('hope', False), False),
#   (('very', False), False),
#   (('much', False), False),
#   (('that', False), False),
#   (('we', False), False),
#   (('would', False), False),
#   (("n't", False), False),
#   (('end', False), False),
#   (('up', False), False),
#   (('in', False), False),
#   (('a', False), False),
#   (('kind', False), False),
#   (('of', False), False),
#   (('situation', False), False),
#   (('where', True), False),
#   (('you', True), False),
#   (('have', True), False),
#   (('a', True), False),
#   (('bidding', True), False),
#   (('war', True), False),
#   (('and', False), False)],
#  [(('``', False), False),
#   (('Everybody', False), False),
#   (('appreciates', False), False),
#   (('that', True), False),
#   (('it', True), False),
#   (('is', True), False),
#   (('a', True), False),
#   (('national', True), False),
#   (('disaster', True), False)],
#  [(('The', True), False),
#   (('company', True), False),
#   (('had', True), False),
#   (('losses', True), False),
#   (('for', True), False),
#   (('several', True), False),
#   (('years', True), False)],
#  [(('In', True), True),
#   (('the', True), True),
#   (('year', True), True),
#   (('ended', True), True),
#   (('Jan.', True), True),
#   (('31', True), True),
#   ((',', True), False),
#   (('Pace', True), False),
#   (('rang', True), False),
#   (('up', True), False),
#   (('profit', True), False),
#   (('of', True), False),
#   (('$', True), True),
#   (('9.4', True), True),
#   (('million', True), True),
#   ((',', True), False),
#   (('or', True), False),
#   (('72', True), False),
#   (('cents', True), False),
#   (('a', True), False),
#   (('share', True), False),
#   ((',', True), False),
#   (('after', True), False),
#   (('a', True), False),
#   (('tax-loss', True), False),
#   (('carry-forward', True), False),
#   ((',', True), False),
#   (('on', True), False),
#   (('sales', True), False),
#   (('of', True), False),
#   (('$', True), True),
#   (('1.3', True), True),
#   (('billion', True), True),
#   ((',', False), False)],
#  [(('The', True), True),
#   (('proposed', True), True),
#   (('merger', True), True),
#   (('comes', True), True),
#   (('The', False), True),
#   (('proposed', False), True),
#   (('merger', False), True),
#   (('comes', False), True),
#   (('as', True), True),
#   (('K', True), True),
#   (('mart', True), True),
#   (("'s", True), True),
#   (('profit', True), True),
#   (('is', True), True),
#   (('declining', True), True)],
#  [(('FileNet', False), False),
#   (('noted', False), False),
#   (('that', True), False),
#   (('it', True), False),
#   (('had', True), False),
#   (('cash', True), False),
#   (('and', True), False),
#   (('marketable', True), False),
#   (('securities', True), False),
#   (('totaling', True), True),
#   (('$', True), True),
#   (('22.5', True), True),
#   (('million', True), True),
#   (('on', True), True),
#   (('Sept.', True), True),
#   (('30', True), True),
#   ((',', False), False)],
#  [(('The', False), False),
#   (('Treasury', False), False),
#   (('also', False), False),
#   (('said', False), False),
#   (('noncompetitive', True), False),
#   (('tenders', True), False),
#   (('will', True), False),
#   (('be', True), False),
#   (('considered', True), False),
#   (('timely', True), False)],
#  [(('A', True), True),
#   (('hearing', True), True),
#   (('is', True), True),
#   (('set', True), True),
#   (('for', True), True),
#   (('Nov.', True), True),
#   (('15', True), True),
#   ((',', False), False)],
#  [(('Secured', True), False),
#   (('creditors', True), False),
#   (('would', True), False),
#   (('recover', True), False),
#   (('both', True), False),
#   (('principal', True), False),
#   (('and', True), False),
#   (('interest', True), False),
#   ((',', False), False),
#   (('Secured', False), False),
#   (('creditors', False), False),
#   (('would', False), False),
#   (('recover', False), False),
#   (('both', False), False),
#   (('principal', False), False),
#   (('and', False), False),
#   (('interest', False), False),
#   ((',', False), False),
#   (('while', False), False),
#   (('unsecured', False), False),
#   (('creditors', False), False),
#   (('would', False), False),
#   (('receive', False), False),
#   (('only', False), False),
#   (('principal', False), False),
#   (('and', False), False),
#   (('interest', False), False),
#   (('accrued', True), False)],
#  [(('GE', False), False),
#   (('Capital', False), False),
#   (('said', False), False),
#   (('Commercial', True), False),
#   (('Federal', True), False),
#   (('Savings', True), False),
#   (('will', True), False),
#   (('continue', True), False),
#   (('to', True), False),
#   (('market', True), False),
#   (('Visa', True), False),
#   (('and', True), False),
#   (('MasterCard', True), False),
#   (('programs', True), False)],
#  [(('After', False), True),
#   (('the', False), True),
#   (('earthquake', False), True),
#   (('two', False), True),
#   (('weeks', False), True),
#   (('ago', False), True),
#   ((',', False), False),
#   (('brokers', False), False),
#   (('say', False), False),
#   (('companies', True), False),
#   (('scrambled', True), False),
#   (('to', True), False),
#   (('replace', True), False),
#   (('reinsurance', True), False),
#   (('coverages', True), False),
#   (('again', True), False)],
#  [(('A', True), False),
#   (('few', True), False),
#   (('years', True), False),
#   (('ago', True), False),
#   ((',', True), False),
#   (('State', True), False),
#   (('Farm', True), False),
#   ((',', True), False),
#   (('the', True), False),
#   (('nation', True), False),
#   (("'s", True), False),
#   (('largest', True), False),
#   (('home', True), False),
#   (('insurer', True), False),
#   ((',', True), False),
#   (('stopped', True), False),
#   (('buying', True), False),
#   (('reinsurance', True), False),
#   (('A', False), False),
#   (('few', False), False),
#   (('years', False), False),
#   (('ago', False), False),
#   ((',', False), False),
#   (('State', False), False),
#   (('Farm', False), False),
#   ((',', False), False),
#   (('the', False), False),
#   (('nation', False), False),
#   (("'s", False), False),
#   (('largest', False), False),
#   (('home', False), False),
#   (('insurer', False), False),
#   ((',', False), False),
#   (('stopped', False), False),
#   (('buying', False), False),
#   (('reinsurance', False), False),
#   (('because', True), False),
#   (('no', True), False),
#   (('one', True), False),
#   (('carrier', True), False),
#   (('could', True), False),
#   (('provide', True), False),
#   (('all', True), False),
#   (('the', True), False),
#   (('coverage', True), False),
#   (('that', True), False),
#   (('it', True), False),
#   (('needed', True), False)],
#  [(('Transamerica', True), False),
#   (('expects', True), False),
#   (('an', True), False),
#   (('after-tax', True), False),
#   (('charge', True), False),
#   (('of', True), False),
#   (('less', True), True),
#   (('than', True), True),
#   (('$', True), True),
#   (('3', True), True),
#   (('million', True), True),
#   (('against', True), True),
#   (('fourth-quarter', True), True),
#   (('net', True), True),
#   ((';', True), False),
#   (('Hartford', True), False),
#   (('Insurance', True), False),
#   (('Group', True), False),
#   ((',', True), False),
#   (('a', True), False),
#   (('unit', True), False),
#   (('of', True), False),
#   (('ITT', True), False),
#   (('Corp.', True), False),
#   ((',', True), False),
#   (('expects', True), False),
#   (('a', True), False),
#   (('$', True), True),
#   (('15', True), True),
#   (('million', True), True),
#   (('or', True), True),
#   (('10', True), True),
#   (('cents', True), True),
#   (('after-tax', True), True),
#   (('charge', True), True),
#   ((';', False), False),
#   (('Transamerica', False), False),
#   (('expects', False), False),
#   (('an', False), False),
#   (('after-tax', False), False),
#   (('charge', False), False),
#   (('of', False), False),
#   (('less', False), False),
#   (('than', False), False),
#   (('$', False), True),
#   (('3', False), True),
#   (('million', False), True),
#   (('against', False), True),
#   (('fourth-quarter', False), True),
#   (('net', False), True),
#   ((';', False), False),
#   (('Hartford', False), False),
#   (('Insurance', False), False),
#   (('Group', False), False),
#   ((',', False), False),
#   (('a', False), False),
#   (('unit', False), False),
#   (('of', False), False),
#   (('ITT', False), False),
#   (('Corp.', False), False),
#   ((',', False), False),
#   (('expects', False), False),
#   (('a', False), False),
#   (('$', False), True),
#   (('15', False), True),
#   (('million', False), True),
#   (('or', False), True),
#   (('10', False), True),
#   (('cents', False), True),
#   (('after-tax', False), True),
#   (('charge', False), True),
#   ((';', False), False),
#   (('and', True), False),
#   (('Fireman', True), False),
#   (("'s", True), False),
#   (('Fund', True), False),
#   (('Corp.', True), False),
#   (('expects', True), False),
#   (('a', True), False),
#   (('charge', True), False),
#   (('of', True), False),
#   (('no', True), False),
#   (('more', True), False),
#   (('than', True), False),
#   (('$', True), True),
#   (('50', True), True),
#   (('million', True), True),
#   (('before', True), True),
#   (('taxes', True), True),
#   (('and', False), True)],
#  [(('That', True), True), (("'s", True), True)],
#  [(('James', False), False),
#   (('Snedeker', False), False),
#   ((',', False), False),
#   (('senior', False), False),
#   (('vice', False), False),
#   (('president', False), False),
#   (('of', False), False),
#   (('Gill', False), False),
#   (('&', False), False),
#   (('Roeser', False), False),
#   (('Inc.', False), False),
#   ((',', False), False),
#   (('a', False), False),
#   (('New', False), False),
#   (('York-based', False), False),
#   (('reinsurance', False), False),
#   (('broker', False), False),
#   ((',', False), False),
#   (('says', False), False),
#   (('insurers', True), False),
#   (('who', True), False),
#   (('took', True), False),
#   (('big', True), False),
#   (('losses', True), False),
#   (('this', True), False),
#   (('fall', True), False),
#   (('and', True), False),
#   (('had', True), False),
#   (('purchased', True), False),
#   (('little', True), False),
#   (('reinsurance', True), False),
#   (('in', True), False),
#   (('recent', True), False),
#   (('years', True), False),
#   (('will', True), False),
#   (('be', True), False),
#   (('asked', True), False),
#   (('to', True), False),
#   (('pay', True), False),
#   (('some', True), False),
#   (('pretty', True), False),
#   (('hefty', True), False),
#   (('rates', True), False)],
#  [(('Insurers', True), True),
#   (('may', True), True),
#   (('see', True), True),
#   (('claims', True), True),
#   (('resulting', True), True),
#   (('from', True), True),
#   (('the', True), True),
#   (('San', True), True),
#   (('Francisco', True), True),
#   (('earthquake', True), True),
#   (('totaling', True), True),
#   (('nearly', True), True),
#   (('$', True), True),
#   (('1', True), True),
#   (('billion', True), True),
#   (('--', True), False),
#   (('far', True), False),
#   (('less', True), False),
#   (('than', True), False),
#   (('the', True), False),
#   (('claims', True), False),
#   (('they', True), False),
#   (('face', True), False),
#   (('from', True), False),
#   (('Hurricane', True), True),
#   (('Hugo', True), True),
#   (('--', False), False)],
#  [(('Insurers', True), True),
#   (('buy', True), True),
#   (('this', True), True),
#   (('insurance', True), True),
#   (('protection', True), True),
#   (('for', True), True),
#   (('themselves', True), True),
#   (('by', True), True),
#   (('giving', True), True),
#   (('up', True), True),
#   (('a', True), True),
#   (('portion', True), True),
#   (('of', True), True),
#   (('the', True), True),
#   (('premiums', True), True),
#   (('they', True), True),
#   (('collect', True), True),
#   (('on', True), True),
#   (('a', True), True),
#   (('policy', True), True),
#   (('to', True), True),
#   (('another', True), True),
#   (('firm', True), True),
#   (('--', True), False),
#   (('a', True), False),
#   (('reinsurance', True), False),
#   (('company', True), False),
#   ((',', False), False),
#   (('which', False), False),
#   ((',', False), False)],
#  [(('The', False), False),
#   (('commission', False), False),
#   (('found', False), False),
#   (('that', True), False)],
#  [(('It', True), True),
#   (("'s", True), True),
#   (('written', True), True),
#   (('`', True), True),
#   (('marcato', True), True),
#   (("'", True), True),
#   (('in', True), True),
#   (('the', True), True),
#   (('score', True), True),
#   ((',', False), False)],
#  [(('``', False), False),
#   (('He', True), False),
#   (('did', True), False),
#   (("n't", True), False),
#   (('say', True), False),
#   (('much', True), False),
#   ((',', False), False),
#   (('``', False), False),
#   (('He', False), False),
#   (('did', False), False),
#   (("n't", False), False),
#   (('say', False), False),
#   (('much', False), False),
#   ((',', False), False),
#   (('but', True), False),
#   (('what', True), False),
#   (('he', True), False),
#   (('said', True), False),
#   (('was', True), False),
#   (('important', True), False)],
#  [(('There', False), False),
#   (("'s", False), False),
#   (('a', False), False),
#   (('beautiful', False), False),
#   ((',', False), False),
#   (('Coplandesque', False), False),
#   (('motif', False), False),
#   (('--', False), False),
#   (('he', True), False),
#   (("'d", True), False),
#   (('kill', True), False),
#   (('me', True), False)],
#  [(('Now', True), True), ((',', False), False)],
#  [(('``', False), False),
#   (('I', True), False),
#   (('did', True), False),
#   (("n't", True), False),
#   (('learn', True), False),
#   (('to', True), False),
#   (('count', True), False)],
#  [(('The', True), True),
#   (('second', True), True),
#   (('incident', True), True),
#   (('took', True), True),
#   (('place', True), True)],
#  [(('``', False), False),
#   (('That', True), False),
#   (("'s", True), False),
#   (('the', True), False),
#   (('most', True), False),
#   (('important', True), False),
#   (('experience', True), False),
#   (('I', True), False),
#   (("'ve", True), False),
#   (('had', True), False),
#   (('with', True), False),
#   (('any', True), False),
#   (('teacher', True), False),
#   ((',', False), False),
#   (("''", False), False),
#   (('he', False), False),
#   (('says', False), False),
#   ((',', False), False),
#   (('``', False), False)],
#  [(('``', False), False)],
#  [(('``', False), False), (('But', True), False)],
#  [(('``', False), False),
#   (('We', True), False),
#   (('listened', True), False),
#   (('to', True), False),
#   (('the', True), False),
#   (('Chausson', True), False),
#   (('`', True), False),
#   (('Poeme', True), False),
#   ((',', False), False),
#   (("'", False), False),
#   (("''", False), False),
#   (('he', False), False),
#   (('recalls', False), False),
#   ((',', False), False),
#   (('``', False), False)],
#  [(('Unfortunately', True), True),
#   ((',', True), False),
#   (('his', True), False),
#   (('mother', True), False),
#   (('had', True), False),
#   (('tickets', True), False),
#   (('for', True), False),
#   (('a', True), False),
#   (('recital', True), False),
#   (('by', True), False),
#   (('Itzhak', True), False),
#   (('Perlman', True), False),
#   (('the', True), False),
#   (('same', True), False),
#   (('night', True), False),
#   ((',', False), False)],
#  [(('His', False), True),
#   (('violin', False), True),
#   (('classmates', False), True),
#   (('included', False), True),
#   (('Shlomo', False), True),
#   (('Mintz', False), True),
#   ((',', False), False),
#   (('a', False), False),
#   (('protege', False), False),
#   (('of', False), False),
#   (('Isaac', False), False),
#   (('Stern', False), False),
#   (('who', True), False),
#   (('performed', True), False),
#   (('with', True), False),
#   (('major', True), False),
#   (('orchestras', True), False)],
#  [(('``', False), False),
#   (('Maybe', True), False),
#   (('I', True), False),
#   (("'m", True), False),
#   (('a', True), False),
#   (('little', True), False),
#   (('stuffy', True), False),
#   ((',', False), False)],
#  [(('``', False), False),
#   (('Maybe', True), False),
#   (('three', True), False),
#   (('years', True), False),
#   (('ago', True), False),
#   ((',', True), False),
#   (('there', True), False),
#   (('were', True), False),
#   (('a', True), False),
#   (('lot', True), False),
#   (('of', True), False),
#   (('-LCB-', True), False),
#   (('Ty', True), False),
#   (('-RCB-', True), False),
#   (('Cobbs', True), False),
#   (('in', True), False),
#   (('the', True), False),
#   (('hobby', True), False),
#   ((',', False), False)],
#  [(('Michigan', True), False),
#   (("'s", True), False),
#   (('Senate', True), False),
#   (('passed', True), False),
#   (('a', True), False),
#   (('bill', True), False),
#   (('requiring', True), False),
#   (('girls', True), False),
#   (('to', True), False),
#   (('get', True), False),
#   (('parental', True), False),
#   (('consent', True), False),
#   (('for', True), False),
#   (('an', True), False),
#   (('abortion', True), False)],
#  [(('In', True), True),
#   (('the', True), True),
#   (('San', True), True),
#   (('Francisco', True), True),
#   (('Bay', True), True),
#   (('area', True), True),
#   ((',', True), False),
#   (('more', True), True),
#   (('than', True), True),
#   (('13,000', True), True),
#   (('people', True), True),
#   (('were', True), True),
#   (('homeless', True), True)],
#  [(('The', True), True), (('action', True), True), (('came', True), True)],
#  [(('A', True), True),
#   (('landslide', True), True),
#   (('engulfed', True), True),
#   (('a', True), True),
#   (('hillside', True), True),
#   (('slum', True), True),
#   (('in', True), True),
#   (('Sao', True), True),
#   (('Paulo', True), True),
#   ((',', True), False),
#   (('Brazil', True), False),
#   ((',', False), False)],
#  [(('Mr.', False), False),
#   (('Lorenzo', False), False),
#   ((',', False), False),
#   (('49', False), False),
#   (('years', False), False),
#   (('old', False), False),
#   ((',', False), False),
#   (('is', False), False),
#   (('reclaiming', False), False),
#   (('the', False), False),
#   (('job', False), False),
#   (('that', True), False),
#   (('was', True), False),
#   (('his', True), False)],
#  [(('The', True), True),
#   (('48-year-old', True), True),
#   (('Mr.', True), True),
#   (('Corr', True), True),
#   (('was', True), True),
#   (('hired', True), True),
#   (('The', False), True),
#   (('48-year-old', False), True),
#   (('Mr.', False), True),
#   (('Corr', False), True),
#   (('was', False), True),
#   (('hired', False), True),
#   (('largely', False), True),
#   (('because', False), True),
#   (('he', False), True),
#   (('was', False), True),
#   (('credited', False), True),
#   (('with', True), True),
#   (('returning', True), True),
#   (('Trans', True), True),
#   (('World', True), True),
#   (('Airlines', True), True),
#   (('Inc.', True), True),
#   (('to', True), True),
#   (('profitability', True), True)],
#  [(('Investment', False), False),
#   (('letters', False), False),
#   (('now', False), False),
#   (('abound', False), False),
#   ((',', False), False),
#   (('I', False), False),
#   (('really', False), False),
#   (('like', False), False),
#   (('to', False), False),
#   (('read', False), False),
#   (('them', False), False),
#   ((';', False), False)],
#  [(('``', False), False),
#   (('I', True), False),
#   (("'m", True), False),
#   (('outraged', True), False),
#   (('``', False), False),
#   (('I', False), False),
#   (("'m", False), False),
#   (('outraged', False), False),
#   (('because', True), False),
#   (('this', True), False),
#   (('company', True), False),
#   (('is', True), False),
#   (('portraying', True), False),
#   (('itself', True), False),
#   (('at', True), False),
#   (('the', True), False),
#   (('heart', True), False),
#   (('of', True), False),
#   (('American', True), False),
#   (('culture', True), False),
#   (('and', True), False),
#   (('political', True), False),
#   (('freedom', True), False),
#   (('``', False), False),
#   (('I', False), False),
#   (("'m", False), False),
#   (('outraged', False), False),
#   (('because', True), False),
#   (('this', True), False),
#   (('company', True), False),
#   (('is', True), False),
#   (('portraying', True), False),
#   (('itself', True), False),
#   (('at', True), False),
#   (('the', True), False),
#   (('heart', True), False),
#   (('of', True), False),
#   (('American', True), False),
#   (('culture', True), False),
#   (('and', True), False),
#   (('political', True), False),
#   (('freedom', True), False),
#   (('and', False), False)],
#  [(('But', True), False)],
#  [(('Although', False), True),
#   (('Philip', False), True),
#   (('Morris', False), True),
#   (('typically', False), True),
#   (('tries', False), True),
#   (('to', False), True),
#   (('defend', False), True),
#   (('the', False), True),
#   (('rights', False), True),
#   (('of', False), True),
#   (('smokers', False), True),
#   (('with', False), True),
#   (('free-choice', False), True),
#   (('arguments', False), True),
#   ((',', False), False),
#   (('``', False), False),
#   (('this', True), False),
#   (('has', True), False),
#   (('nothing', True), False),
#   (('to', True), False),
#   (('do', True), False),
#   (('with', True), False),
#   (('cigarettes', True), False),
#   ((',', False), False)],
#  [(('The', False), True),
#   (('company', False), True),
#   (("'s", False), True),
#   (('research', False), True),
#   (('suggests', False), True),
#   (('that', True), True),
#   (('its', True), True),
#   (('name', True), True),
#   (('recognition', True), True),
#   (('among', True), True),
#   (('most', True), True),
#   (('consumers', True), True),
#   (('remains', True), True),
#   (('unusually', True), True),
#   (('low', True), True),
#   ((',', False), False)],
#  [(('``', False), False)],
#  [(('Many', True), True),
#   (('marketers', True), True),
#   (('say', True), True),
#   (('Philip', True), True),
#   (('Morris', True), True),
#   (("'s", True), True),
#   (('approach', True), True),
#   (('will', True), True),
#   (('be', True), True),
#   (('effective', True), True),
#   ((',', False), False)],
#  [(('With', True), True),
#   (('this', True), True),
#   (('treatment', True), True),
#   (('we', True), True),
#   (('have', True), True),
#   (('reduced', True), True),
#   (('deaths', True), True),
#   (('in', True), True),
#   (('high-risk', True), True),
#   (('colon', True), True),
#   (('cancer', True), True),
#   (('by', True), True),
#   (('one-third', True), True),
#   (('--', False), False)],
#  [(('I', False), False),
#   (('feel', False), False),
#   (('any', True), False),
#   (('patient', True), False),
#   (('with', True), False),
#   (('high-risk', True), False),
#   (('cancer', True), False),
#   (('is', True), False),
#   (('getting', True), False),
#   (('short', True), False),
#   (('shrift', True), False)],
#  [(('I', True), True),
#   (('did', True), True),
#   (("n't", True), True),
#   (('say', True), True),
#   (('this', True), True),
#   ((',', False), False)],
#  [(('In', False), False),
#   (('this', False), False),
#   (('article', False), False),
#   ((',', False), False),
#   (('I', False), False),
#   (('was', False), False),
#   (('alleged', False), False),
#   (('to', False), False),
#   (('have', False), False),
#   (('said', False), False),
#   ((',', False), False),
#   (('``', False), False),
#   (('Any', True), False),
#   (('patient', True), False),
#   (('with', True), False),
#   (('high-risk', True), False),
#   (('colon', True), False),
#   (('cancer', True), False),
#   (('is', True), False),
#   (('really', True), False),
#   (('getting', True), False),
#   (('short', True), False),
#   (('shrift', True), False)],
#  [(('This', True), False),
#   (('hope', True), False),
#   ((',', True), False),
#   (('however', True), False),
#   ((',', True), False),
#   (('will', True), False),
#   (('never', True), False),
#   (('be', True), False),
#   (('realized', True), False)],
#  [(('It', False), True),
#   (('has', False), True),
#   (("n't", False), True),
#   (('helped', False), True),
#   (('that', True), True),
#   (('he', True), True),
#   (("'s", True), True),
#   (('waffled', True), True),
#   (('on', True), True),
#   (('abortion', True), True),
#   (('and', True), True),
#   (('gay', True), True),
#   (('rights', True), True),
#   ((',', True), False),
#   (('sought', True), False),
#   (('the', True), False),
#   (('support', True), False),
#   (('of', True), False),
#   (('both', True), False),
#   (('the', True), False),
#   (('Liberal', True), False),
#   (('and', True), False),
#   (('Conservative', True), False),
#   (('parties', True), False),
#   (('-LRB-', False), False),
#   (('he', False), False),
#   (('won', False), False),
#   (('the', False), False),
#   (('Liberal', False), False),
#   (('endorsement', False), False),
#   (('-RRB-', False), False)],
#  [(('Both', True), True),
#   (('candidates', True), True),
#   (('are', True), True),
#   (('negotiating', True), True),
#   (('about', True), True),
#   (('holding', True), True),
#   (('debates', True), True),
#   ((',', False), False)],
#  [(('Mr.', True), False),
#   (('Mason', True), False),
#   (('left', True), False),
#   (('the', True), False),
#   (('campaign', True), False)],
#  [(('He', True), False),
#   (("'s", True), False),
#   (('had', True), False),
#   (('a', True), False),
#   (('history', True), False),
#   (('of', True), False),
#   (('deception', True), False)],
#  [(('Republicans', False), False),
#   (('figured', False), False),
#   (('that', True), False),
#   (('in', True), False),
#   (('Mr.', True), False),
#   (('Giuliani', True), False),
#   ((',', True), False),
#   (('the', True), False),
#   (('nation', True), False),
#   (("'s", True), False),
#   (('best-known', True), False),
#   (('prosecutor', True), False),
#   ((',', True), False),
#   (('they', True), False),
#   (('had', True), False),
#   (('a', True), False),
#   (('chance', True), False),
#   (('for', True), False),
#   (('a', True), False),
#   (('huge', True), False),
#   (('upset', True), False),
#   (('in', True), False),
#   (('the', True), False),
#   (('heart', True), False),
#   (('of', True), False),
#   (('Democratic', True), False),
#   (('territory', True), False)],
#  [(('This', True), True),
#   (('is', True), True),
#   (('the', True), True),
#   (('nation', True), True),
#   (("'s", True), True),
#   (('biggest', True), True),
#   (('city', True), True)],
#  [(('It', False), True),
#   (('began', False), True),
#   (('in', False), True),
#   (('1973', False), True),
#   ((',', False), False),
#   (('when', True), False),
#   (('he', True), False),
#   (('was', True), False),
#   (('being', True), False),
#   (('considered', True), False),
#   (('for', True), False),
#   (('deputy', True), False),
#   (('mayor', True), False),
#   ((',', False), False)],
#  [(('For', True), True), ((',', False), False)],
#  [(('Mr.', True), False),
#   (('Dinkins', True), False),
#   ((',', True), False),
#   (('the', True), False),
#   (('Manhattan', True), False),
#   (('borough', True), False),
#   (('president', True), False),
#   ((',', True), False),
#   (('can', True), False),
#   (('afford', True), False),
#   (('more', True), False),
#   (('bumbling', True), False),
#   (('and', True), False),
#   (('stumbling', True), False)],
#  [(('He', True), False),
#   (('defeated', True), False),
#   (('the', True), False),
#   (('contentious', True), False),
#   (('Mr.', True), False),
#   (('Koch', True), False),
#   (('in', True), False),
#   (('the', True), False),
#   (('Democratic', True), False),
#   (('primary', True), False)],
#  [(('He', True), False),
#   (('waits', True), False),
#   (('to', True), False),
#   (('talk', True), False),
#   (('about', True), False),
#   (('it', True), False),
#   (('He', False), False),
#   (('waits', False), False),
#   (('to', True), False),
#   (('talk', True), False),
#   (('about', True), False),
#   (('it', True), False),
#   (('until', False), False)],
#  [(('Last', True), False),
#   (('year', True), False),
#   (('catastrophe', True), False),
#   (('losses', True), False),
#   (('totaled', True), False),
#   (('$', True), False),
#   (('5', True), True),
#   (('million', True), True),
#   ((',', False), False)],
#  [(('But', True), False)],
#  [(('During', True), True),
#   (('the', True), True),
#   (('latter', True), True),
#   (('part', True), True),
#   (('of', True), True),
#   (('the', True), True),
#   (('19th', True), True),
#   (('century', True), True),
#   ((',', True), False),
#   (('Russia', True), False),
#   (('was', True), False),
#   (('on', True), False),
#   (('a', True), False),
#   (('gold', True), False),
#   (('standard', True), False),
#   (('and', True), False),
#   (('had', True), False),
#   (('gold', True), False),
#   (('reserves', True), True),
#   (('representing', True), True),
#   (('more', True), True),
#   (('than', True), True),
#   (('100', True), True),
#   (('%', True), True),
#   (('of', True), True),
#   (('its', True), True),
#   (('outstanding', True), True),
#   (('currency', True), True),
#   ((',', False), False)],
#  [(('By', False), True),
#   (('contrast', False), True),
#   ((',', False), False),
#   (('in', False), False),
#   (('19th-century', False), False),
#   (('Russia', False), False),
#   (('an', False), False),
#   (('authoritarian', False), False),
#   (('government', False), False),
#   (('owned', False), False),
#   (('the', False), False),
#   (('bank', False), False),
#   (('and', True), False),
#   (('had', True), False),
#   (('the', True), False),
#   (('power', True), False),
#   (('to', True), False),
#   (('revoke', True), False),
#   (('payment', True), False),
#   (('whenever', True), False),
#   (('it', True), False),
#   (('chose', True), False),
#   ((',', False), False)],
#  [(('The', True), True),
#   (('Bank', True), True),
#   (('of', True), True),
#   (('England', True), True),
#   ((',', True), False),
#   (('on', True), False),
#   (('the', True), False),
#   (('other', True), False),
#   (('hand', True), False),
#   ((',', True), False),
#   (('had', True), False),
#   (('gold', True), False),
#   (('reserves', True), True),
#   (('that', True), True),
#   (('averaged', True), True),
#   (('about', True), True),
#   (('30', True), True),
#   (('%', True), True),
#   (('of', True), True),
#   (('its', True), True),
#   (('outstanding', True), True),
#   (('currency', True), True),
#   ((',', False), False)],
#  [(('The', False), True),
#   (('most', False), True),
#   (('likely', False), True),
#   (('reason', False), True),
#   (('for', False), True),
#   (('this', False), True),
#   (('disparity', False), True),
#   (('is', False), True),
#   (('that', True), True),
#   (('the', True), True),
#   (('Bank', True), True),
#   (('of', True), True),
#   (('England', True), True),
#   (('was', True), True),
#   (('a', True), True),
#   (('private', True), True),
#   (('bank', True), True),
#   (('with', True), True),
#   (('substantial', True), True),
#   (('earning', True), True),
#   (('assets', True), True),
#   ((',', False), False)],
#  [(('It', False), True),
#   (('is', False), True),
#   (('no', False), True),
#   (('coincidence', False), True),
#   (('that', False), True),
#   (('from', False), True),
#   (('1844', False), True),
#   (('to', False), True),
#   (('1914', False), True),
#   ((',', False), False),
#   (('when', False), False),
#   (('the', False), False),
#   (('Bank', False), False),
#   (('of', False), False),
#   (('England', False), False),
#   (('was', False), False),
#   (('an', False), False),
#   (('independent', False), False),
#   (('private', False), False),
#   (('bank', False), False),
#   ((',', False), False),
#   (('the', True), False),
#   (('pound', True), False),
#   (('was', True), False),
#   (('never', True), False),
#   (('devalued', True), False),
#   (('It', False), False),
#   (('is', False), False),
#   (('no', False), False),
#   (('coincidence', False), False),
#   (('that', True), False),
#   (('from', True), False),
#   (('1844', True), False),
#   (('to', True), False),
#   (('1914', True), False),
#   ((',', True), False),
#   (('when', True), False),
#   (('the', True), False),
#   (('Bank', True), False),
#   (('of', True), False),
#   (('England', True), False),
#   (('was', True), False),
#   (('an', True), False),
#   (('independent', True), False),
#   (('private', True), False),
#   (('bank', True), False),
#   ((',', True), False),
#   (('the', True), False),
#   (('pound', True), False),
#   (('was', True), False),
#   (('never', True), False),
#   (('devalued', True), False),
#   (('and', True), False),
#   (('payment', True), False),
#   (('of', True), False),
#   (('gold', True), False),
#   (('for', True), False),
#   (('pound', True), False),
#   (('notes', True), False),
#   (('was', True), False),
#   (('never', True), False),
#   (('suspended', True), False),
#   ((',', False), False),
#   (('It', False), False),
#   (('is', False), False),
#   (('no', False), False),
#   (('coincidence', False), False),
#   (('that', False), False),
#   (('from', False), False),
#   (('1844', False), False),
#   (('to', False), False),
#   (('1914', False), False),
#   ((',', False), False),
#   (('when', False), False),
#   (('the', False), False),
#   (('Bank', False), False),
#   (('of', False), False),
#   (('England', False), False),
#   (('was', False), False),
#   (('an', False), False),
#   (('independent', False), False),
#   (('private', False), False),
#   (('bank', False), False),
#   ((',', False), False),
#   (('the', False), False),
#   (('pound', False), False),
#   (('was', False), False),
#   (('never', False), False),
#   (('devalued', False), False),
#   (('and', False), False),
#   (('payment', False), False),
#   (('of', False), False),
#   (('gold', False), False),
#   (('for', False), False),
#   (('pound', False), False),
#   (('notes', False), False),
#   (('was', False), False),
#   (('never', False), False),
#   (('suspended', False), False),
#   ((',', False), False),
#   (('but', True), False),
#   (('with', True), False),
#   (('the', True), False),
#   (('subsequent', True), False),
#   (('nationalization', True), False),
#   (('of', True), False),
#   (('the', True), False),
#   (('Bank', True), False),
#   (('of', True), False),
#   (('England', True), False),
#   ((',', True), False),
#   (('the', True), False),
#   (('pound', True), False),
#   (('was', True), False),
#   (('devalued', True), False),
#   (('with', True), False),
#   (('increasing', True), False),
#   (('frequency', True), False)],
#  [(('Mr.', True), False),
#   (('Angell', True), False),
#   (('is', True), False),
#   (('incorrect', True), False)],
#  [(('The', True), True),
#   (('Soviet', True), True),
#   (('Union', True), True),
#   (('should', True), True),
#   (('keep', True), True),
#   (('these', True), True),
#   (('lessons', True), True),
#   (('in', True), True),
#   (('mind', True), True)],
#  [(('I', True), False),
#   (('read', True), False),
#   (('the', True), False),
#   (('exerpts', True), False),
#   (('of', True), False),
#   (('Wayne', True), False),
#   (('Angell', True), False),
#   (("'s", True), False),
#   (('exchange', True), False),
#   (('with', True), False),
#   (('a', True), False),
#   (('Gosbank', True), False),
#   (('representative', True), False),
#   (('-LRB-', True), False),
#   (('``', True), False),
#   (('Put', True), False),
#   (('the', True), False),
#   (('Soviet', True), False),
#   (('Economy', True), False),
#   (('on', True), False),
#   (('Golden', True), False),
#   (('Rails', True), False),
#   ((',', True), False),
#   (("''", True), False),
#   (('editorial', True), False),
#   (('page', True), False),
#   ((',', True), False),
#   (('Oct.', True), False),
#   (('5', True), False),
#   (('-RRB-', True), False),
#   (('with', True), False),
#   (('great', True), False),
#   (('interest', True), False),
#   ((',', False), False)],
#  [(('The', True), True),
#   (('company', True), True),
#   (('has', True), True),
#   (('declined', True), True),
#   (('requests', True), True),
#   (('to', True), True),
#   (('discuss', True), True),
#   (('the', True), True),
#   (('changes', True), True),
#   ((',', False), False),
#   (('The', True), False),
#   (('company', True), False),
#   (('has', True), False),
#   (('declined', True), False),
#   (('requests', True), True),
#   (('to', True), True),
#   (('discuss', True), True),
#   (('the', True), True),
#   (('changes', True), True),
#   ((',', False), False)],
#  [(('West', True), True),
#   (('Germany', True), True),
#   (('also', True), True),
#   (('has', True), True),
#   (('increased', True), True),
#   (('its', True), True),
#   (('credit', True), True),
#   (('guarantees', True), True),
#   (('to', True), True),
#   (('Hungary', True), True),
#   (('by', True), True),
#   (('500', True), True),
#   (('million', True), True),
#   (('marks', True), True),
#   (('to', True), True),
#   (('1.5', True), True),
#   (('billion', True), True),
#   (('marks', True), True)],
#  [(('Deutsche', False), False),
#   (('Bank', False), False),
#   (('AG', False), False),
#   ((',', False), False),
#   (('which', False), False),
#   (('last', False), False),
#   (('year', False), False),
#   (('arranged', False), False),
#   (('a', False), False),
#   (('three', False), True),
#   (('billion', False), True),
#   (('mark', False), True),
#   (('credit', False), True),
#   (('for', False), True),
#   (('the', False), True),
#   (('Soviet', False), True),
#   (('Union', False), True),
#   ((',', False), False),
#   (('is', False), False),
#   (('now', False), False),
#   (('moving', False), False),
#   (('to', True), False),
#   (('become', True), False),
#   (('the', True), False),
#   (('first', True), False),
#   (('West', True), False),
#   (('German', True), False),
#   (('bank', True), False),
#   (('to', True), False),
#   (('set', True), False),
#   (('up', True), False),
#   (('independent', True), False),
#   (('business', True), False),
#   (('offices', True), False),
#   (('in', True), False),
#   (('Hungary', True), False),
#   (('and', True), False),
#   (('Poland', True), False)],
#  [(('``', False), False),
#   (('The', False), False),
#   (('change', False), False),
#   (('taking', False), False),
#   (('place', False), False),
#   (('in', False), False),
#   (('the', False), False),
#   (('Soviet', False), False),
#   (('Union', False), False),
#   ((',', False), False),
#   (('Poland', False), False),
#   (('and', False), False),
#   (('Hungary', False), False),
#   (('has', False), False),
#   (('aroused', False), False),
#   (('new', False), False),
#   (('hope', False), False),
#   (('in', False), False),
#   (('both', False), False),
#   (('German', False), False),
#   (('states', False), False),
#   (('that', True), False),
#   (('reforms', True), False),
#   (('will', True), False),
#   (('be', True), False),
#   (('undertaken', True), False),
#   (('in', True), False),
#   (('-LCB-', True), False),
#   (('East', True), False),
#   (('Germany', True), False),
#   (('-RCB-', True), False),
#   ((',', False), False)],
#  [(('In', True), True),
#   (('addition', True), True),
#   ((',', True), False),
#   (('a', True), False),
#   (('group', True), False),
#   (('of', True), False),
#   (('24', True), False),
#   (('industrialized', True), False),
#   (('countries', True), False),
#   ((',', True), False),
#   (('including', True), False),
#   (('the', True), False),
#   (('U.S.', True), False),
#   (('and', True), False),
#   (('Japan', True), False),
#   (('and', True), False),
#   (('coordinated', True), False),
#   (('by', True), False),
#   (('the', True), False),
#   (('European', True), False),
#   (('Community', True), False),
#   (('Commission', True), False),
#   ((',', True), False),
#   (('has', True), False),
#   (('promised', True), False),
#   (('Poland', True), False),
#   (('and', True), False),
#   (('Hungary', True), False),
#   (('trade', True), False),
#   (('advice', True), False),
#   (('and', True), False),
#   (('a', True), False),
#   (('line', True), False),
#   (('of', True), False),
#   (('credit', True), False),
#   (('equivalent', True), False),
#   (('to', True), False),
#   (('$', True), False),
#   (('1.11', True), False),
#   (('billion', True), True),
#   (('through', True), True),
#   (('the', True), True),
#   (('European', True), True),
#   (('Investment', True), True),
#   (('Bank', True), True),
#   ((',', False), False)],
#  [(('Bonn', False), False),
#   (('and', False), False),
#   (('Washington', False), False),
#   (('have', False), False),
#   (('taken', False), False),
#   (('a', False), False),
#   (('leading', False), False),
#   (('role', False), False),
#   (('in', False), False),
#   (('aid', False), False),
#   (('for', False), False),
#   (('the', False), False),
#   (('reformist', False), False),
#   (('countries', False), False),
#   ((',', False), False),
#   (('pledging', True), False),
#   (('billions', True), False),
#   (('of', True), False),
#   (('dollars', True), False),
#   (('in', True), False),
#   (('fresh', True), False),
#   (('credit', True), False),
#   (('and', True), False),
#   (('forgiving', True), False),
#   (('old', True), False),
#   (('debt', True), False)],
#  [(('The', True), True),
#   (('package', True), True),
#   (('was', True), True),
#   (('brought', True), True),
#   (('to', True), True),
#   (('the', True), True),
#   (('House', True), True)],
#  [(('The', True), False),
#   (('piano', True), False),
#   (('compositions', True), False),
#   ((',', False), False),
#   (('which', False), False),
#   (('have', False), False),
#   (('been', False), False),
#   (('labeled', False), False),
#   (('variously', False), False),
#   (('as', False), False),
#   (('minimalist', False), False),
#   ((',', False), False),
#   (('Oriental', False), False),
#   ((',', False), False),
#   (('repetitive', False), False),
#   ((',', False), False),
#   (('cyclical', False), False),
#   ((',', False), False),
#   (('monophonic', False), False),
#   (('and', False), False),
#   (('hypnotic', False), False),
#   ((',', False), False),
#   (('are', True), False),
#   (('relentlessly', True), False),
#   (('tonal', True), False),
#   (('-LRB-', False), False),
#   (('The', False), False),
#   (('piano', False), False),
#   (('compositions', False), False),
#   ((',', False), False),
#   (('which', False), False),
#   (('have', False), False),
#   (('been', False), False),
#   (('labeled', False), False),
#   (('variously', False), False),
#   (('as', False), False),
#   (('minimalist', False), False),
#   ((',', False), False),
#   (('Oriental', False), False),
#   ((',', False), False),
# ...
#   (('cut', True), False),
#   (('by', True), False),
#   (('almost', True), False),
#   (('two-thirds', True), False),
#   ((',', False), False)],
#  [(('Much', False), True),
#   (('of', False), True),
#   (('the', False), True),
#   (('excess', False), True),
#   (('spending', False), True),
#   (('will', False), True),
#   (('be', False), True),
#   (('pushed', False), True),
#   (('into', False), True),
#   (('fiscal', False), True),
#   (('1991', False), True),
#   ((',', False), False),
#   (('and', False), False),
#   (('in', False), False),
#   (('some', False), False),
#   (('cases', False), False),
#   (('is', False), False),
#   (('temporarily', False), False),
#   (('parked', False), False),
#   (('in', False), False),
#   (('slow-spending', False), False),
#   (('accounts', False), False),
#   (('in', False), False),
#   (('anticipation', False), False),
#   (('of', True), False),
#   (('being', True), False),
#   (('transferred', True), False),
#   (('to', True), False),
#   (('faster-spending', True), False),
#   (('areas', True), False)],
#  [(('The', True), True),
#   (('fiscal', True), True),
#   (('1990', True), True),
#   (('measure', True), True),
#   (('builds', True), True),
#   (('on', True), True),
#   (('a', True), True),
#   (('pattern', True), True),
#   (('set', True), True),
#   (('earlier', True), True),
#   (('this', True), True),
#   (('year', True), True),
#   (('by', True), True),
#   (('House', True), True),
#   (('and', True), True),
#   (('Senate', True), True),
#   (('defense', True), True),
#   (('authorizing', True), True),
#   (('committees', True), True),
#   ((',', False), False)],
#  [(('The', True), True),
#   (('House', True), True),
#   (('Democratic', True), True),
#   (('leadership', True), True),
#   (('could', True), True),
#   (('seek', True), True),
#   (('to', True), True),
#   (('waive', True), True),
#   (('these', True), True),
#   (('restrictions', True), True),
#   ((',', False), False)],
#  [(('By', True), True),
#   (('an', True), True),
#   (('84-6', True), True),
#   (('margin', True), True),
#   ((',', True), False),
#   (('the', True), False),
#   (('Senate', True), False),
#   (('approved', True), False),
#   (('the', True), False),
#   (('bulk', True), False),
#   (('of', True), False),
#   (('the', True), False),
#   (('spending', True), False),
#   (('Friday', True), False),
#   ((',', False), False),
#   (('By', True), False),
#   (('an', True), False),
#   (('84-6', True), False),
#   (('margin', True), False),
#   ((',', True), False),
#   (('the', True), False),
#   (('Senate', True), False),
#   (('approved', True), False),
#   (('the', True), False),
#   (('bulk', True), False),
#   (('of', True), False),
#   (('the', True), False),
#   (('spending', True), False),
#   (('Friday', True), False),
#   ((',', False), False),
#   (('but', False), False),
#   (('the', False), False),
#   (('bill', False), False),
#   (('was', False), False)],
#  [(('Appropriations', True), False),
#   (('committees', True), False),
#   (('have', True), False),
#   (('used', True), False),
#   (('an', True), False),
#   (('assortment', True), False),
#   (('of', True), False),
#   (('devices', True), False),
#   (('to', True), False),
#   (('disguise', True), False),
#   (('as', True), False),
#   (('much', True), False),
#   (('as', True), False),
#   (('$', True), True),
#   (('1', True), True),
#   (('billion', True), True),
#   (('in', True), True),
#   (('spending', True), True),
#   ((',', False), False),
#   (('Appropriations', False), False),
#   (('committees', False), False),
#   (('have', False), False),
#   (('used', False), False),
#   (('an', False), False),
#   (('assortment', False), False),
#   (('of', False), False),
#   (('devices', False), False),
#   (('to', False), False),
#   (('disguise', False), False),
#   (('as', False), False),
#   (('much', False), False),
#   (('as', False), False),
#   (('$', False), True),
#   (('1', False), True),
#   (('billion', False), True),
#   (('in', False), True),
#   (('spending', False), True),
#   ((',', False), False),
#   (('and', True), False)],
#  [(('Congress', False), False),
#   (('sent', False), False),
#   (('to', False), False),
#   (('President', False), False),
#   (('Bush', False), False),
#   (('an', False), False),
#   (('$', False), False),
#   (('8.5', False), False),
#   (('billion', False), True),
#   (('military', False), True),
#   (('construction', False), True),
#   (('bill', False), True),
#   (('that', True), True),
#   (('cuts', True), True),
#   (('spending', True), True),
#   (('for', True), True),
#   (('new', True), True),
#   (('installations', True), True),
#   (('by', True), True),
#   (('16', True), True),
#   (('%', True), True)],
#  [(('From', False), True),
#   (('what', False), True),
#   (('he', False), True),
#   (('saw', False), True),
#   (('on', False), True),
#   (('television', False), True),
#   ((',', False), False),
#   (('Mr.', False), False),
#   (('Chesley', False), False),
#   (('points', False), False),
#   (('out', False), False),
#   (('that', True), False),
#   (('Interstate', True), False),
#   (('880', True), False),
#   ((',', False), False),
#   (('which', False), False),
#   (('collapsed', False), False),
#   (('and', False), False),
#   (('killed', False), False),
#   (('more', False), False),
#   (('than', False), False),
#   (('200', False), False),
#   (('commuters', False), False),
#   ((',', False), False),
#   (('suffered', True), False),
#   (('serious', True), False),
#   (('damage', True), False)],
#  [(('Defense', False), False),
#   (('lawyers', False), False),
#   ((',', False), False),
#   (('perhaps', False), False),
#   (('understandably', False), False),
#   ((',', False), False),
#   (('say', False), False),
#   (('that', True), False),
#   (('plaintiffs', True), False),
#   (("'", True), False),
#   (('lawyers', True), False),
#   (('taking', True), False),
#   (('such', True), False),
#   (('an', True), False),
#   (('approach', True), False),
#   (('will', True), False),
#   (('have', True), False),
#   (('little', True), False),
#   (('success', True), False),
#   (('in', True), False),
#   (('pursuing', True), False),
#   (('their', True), False),
#   (('claims', True), False),
#   ((',', False), False)],
#  [(('Mr.', True), False),
#   (('Covert', True), False),
#   (('had', True), False),
#   (('to', True), False),
#   (('search', True), False),
#   (('through', True), False),
#   (('law', True), False),
#   (('books', True), False),
#   (('scattered', True), False),
#   (('on', True), False),
#   (('the', True), False),
#   (('floor', True), False),
#   (('of', True), False),
#   (('his', True), False),
#   (('office', True), False),
#   (('yesterday', True), False),
#   ((',', False), False)],
#  [(('The', True), False),
#   (('state', True), False),
#   (('is', True), False),
#   (('protected', True), False),
#   (('The', False), False),
#   (('state', False), False),
#   (('is', False), False),
#   (('protected', False), False),
#   (('when', True), False),
#   (('plans', True), False),
#   (('and', True), False),
#   (('designs', True), False),
#   (('for', True), False),
#   (('public', True), False),
#   (('structures', True), False),
#   (('were', True), False),
#   (('approved', True), False),
#   (('ahead', True), False),
#   (('of', True), False),
#   (('time', True), False),
#   (('The', True), False),
#   (('state', True), False),
#   (('is', True), False),
#   (('protected', True), False),
#   (('when', False), False),
#   (('plans', False), False),
#   (('and', False), False),
#   (('designs', False), False),
#   (('for', False), False),
#   (('public', False), False),
#   (('structures', False), False),
#   (('were', False), False),
#   (('approved', False), False),
#   (('ahead', False), False),
#   (('of', False), False),
#   (('time', False), False),
#   (('or', False), False)],
#  [(('But', True), False)],
#  [(('But', True), False),
#   (('lawyers', True), False),
#   (('looking', True), False),
#   (('to', True), False),
#   (('cash', True), False),
#   (('in', True), False),
#   (('on', True), False),
#   (('the', True), False),
#   (('quake', True), False),
#   (('may', True), False),
#   (('have', True), False),
#   (('a', True), False),
#   (('tough', True), False),
#   (('time', True), False)],
#  [(('Nevertheless', False), False),
#   ((',', False), False),
#   (('he', False), False),
#   (('adds', False), False),
#   ((',', False), False),
#   (('``', False), False),
#   (('I', True), False),
#   (('would', True), False),
#   (("n't", True), False),
#   (('get', True), False),
#   (('totally', True), False),
#   (('shocked', True), False)],
#  [(('``', False), False),
#   (('We', True), False),
#   (('wo', True), False),
#   (("n't", True), False),
#   (('know', True), False),
#   (('``', False), False),
#   (('We', True), False),
#   (('wo', True), True),
#   (("n't", True), True),
#   (('know', True), True),
#   (('until', True), True),
#   (('the', True), True),
#   (('smoke', True), True),
#   (('clears', True), True),
#   (('--', False), False)],
#  [(('Therefore', True), True),
#   ((',', True), False),
#   (('engineering', True), False),
#   (('firms', True), False),
#   ((',', True), False),
#   (('construction', True), False),
#   (('contractors', True), False),
#   (('and', True), False),
#   (('developers', True), False),
#   (('can', True), False),
#   (('be', True), False),
#   (('sued', True), False),
#   (('for', True), False),
#   (('not', True), False),
#   (('keeping', True), False),
#   (('structures', True), False),
#   (('up', True), False),
#   (('to', True), False),
#   (('standard', True), False),
#   ((',', False), False),
#   (('Therefore', False), False),
#   ((',', False), False),
#   (('engineering', False), False),
#   (('firms', False), False),
#   ((',', False), False),
#   (('construction', False), False),
#   (('contractors', False), False),
#   (('and', False), False),
#   (('developers', False), False),
#   (('can', False), False),
#   (('be', False), False),
#   (('sued', False), False),
#   (('for', False), False),
#   (('not', False), False),
#   (('keeping', False), False),
#   (('structures', False), False),
#   (('up', False), False),
#   (('to', False), False),
#   (('standard', False), False),
#   ((',', False), False),
#   (('and', True), False),
#   (('government', True), False),
#   (('agencies', True), False),
#   (('can', True), False),
#   (('be', True), False),
#   (('held', True), False),
#   (('accountable', True), False),
#   (('for', True), False),
#   (('failing', True), False),
#   (('to', True), False),
#   (('properly', True), False),
#   (('protect', True), False),
#   (('citizens', True), False),
#   (('from', True), False),
#   (('such', True), False),
#   (('a', True), False),
#   (('foreseeable', True), False),
#   (('disaster', True), False),
#   ((',', False), False)],
#  [(('For', False), True),
#   (('now', False), True),
#   ((',', False), False),
#   (('says', False), False),
#   (('Laurence', False), False),
#   (('Drivon', False), False),
#   ((',', False), False),
#   (('president-elect', False), False),
#   (('of', False), False),
#   (('the', False), False),
#   (('6,000-member', False), False),
#   (('California', False), False),
#   (('Trial', False), False),
#   (('Lawyers', False), False),
#   (('Association', False), False),
#   ((',', False), False),
#   (('``', False), False),
#   (('the', False), False),
#   (('last', False), False),
#   (('thing', False), False),
#   (('we', False), False),
#   (('really', False), False),
#   (('need', False), False),
#   (('to', False), False),
#   (('worry', False), False),
#   (('about', False), False),
#   (('is', False), False),
#   (('whether', True), False),
#   (('anybody', True), False),
#   (('is', True), False),
#   (('going', True), False),
#   (('to', True), False),
#   (('get', True), False),
#   (('sued', True), False),
#   ((',', False), False)],
#  [(('``', False), False),
#   (('We', True), False),
#   (('did', True), False),
#   (('see', True), False),
#   (('some', True), False),
#   (('relief', True), False),
#   (('in', True), False),
#   (('raw', True), False),
#   (('material', True), False),
#   (('costs', True), False),
#   ((',', False), False)],
#  [(('Some', True), False),
#   (('tariffs', True), False),
#   (('were', True), False),
#   (('eliminated', True), False)],
#  [(('U.S.', True), False),
#   (('exports', True), True),
#   (('to', True), True),
#   (('Canada', True), True),
#   (('jumped', True), True),
#   (('11.2', True), True),
#   (('%', True), True),
#   (('in', True), True),
#   (('August', True), True),
#   (('from', True), True),
#   (('July', True), True)],
#  [(('Remaining', True), True),
#   (('units', True), True),
#   (('will', True), True),
#   (('be', True), True),
#   (('sold', True), True),
#   (('to', True), True),
#   (('the', True), True),
#   (('underwriters', True), True),
#   ((',', True), False),
#   (('Drexel', True), False),
#   (('Burnham', True), False),
#   (('Lambert', True), False),
#   (('Inc.', True), False),
#   (('and', True), False),
#   (('Kidder', True), False),
#   ((',', True), False),
#   (('Peabody', True), False),
#   (('&', True), False),
#   (('Co.', False), False),
#   ((',', False), False),
#   (('which', False), False),
#   (('will', False), False)],
#  [(('No', True), True),
#   (('schedule', True), True),
#   (('for', True), True),
#   (('formal', True), True),
#   (('talks', True), True),
#   (('was', True), True),
#   (('set', True), True),
#   ((',', False), False)],
#  [(('The', True), True),
#   (('union', True), True),
#   (('called', True), True),
#   (('the', True), True),
#   (('strike', True), True),
#   (('in', True), True),
#   (('April', True), True)],
#  [(('Stock', True), True),
#   (('prices', True), True),
#   (('rose', True), True),
#   (('slightly', True), True),
#   (('Stock', True), True),
#   (('prices', True), True),
#   (('rose', True), True),
#   (('slightly', True), True),
#   (('as', True), True),
#   (('trading', True), True),
#   (('slowed', True), True),
#   ((',', False), False)],
#  [(('The', True), True),
#   (('buy-back', True), True),
#   ((',', True), False),
#   (('which', True), False),
#   (('was', True), False),
#   (("n't", True), False),
#   (('a', True), False),
#   (('complete', True), False),
#   (('surprise', True), False),
#   ((',', True), False),
#   (('was', True), False),
#   (('announced', True), False)],
#  [(('``', False), False),
#   (('We', True), False),
#   (('had', True), False),
#   (('underfunded', True), False),
#   (('Maalox', True), False),
#   (('for', True), False),
#   (('a', True), False),
#   (('year', True), False),
#   ((',', False), False),
#   (("''", False), False),
#   (('he', False), False),
#   (('said', False), False),
#   ((',', False), False)],
#  [(('Mr.', False), False),
#   (('Cawthorn', False), False),
#   (('attributed', False), False),
#   (('the', False), False),
#   (('decline', False), False),
#   (('in', False), False),
#   (('third-quarter', False), False),
#   (('operating', False), False),
#   (('profit', False), False),
#   (('to', False), False),
#   (('the', False), False),
#   (('stronger', False), False),
#   (('dollar', False), False),
#   ((',', False), False),
#   (('which', True), False),
#   (('reduces', True), False),
#   (('the', True), False),
#   (('value', True), False),
#   (('of', True), False),
#   (('overseas', True), False),
#   (('profit', True), False)],
#  [(('Rorer', False), False),
#   (('Group', False), False),
#   (('Inc.', False), False),
#   (('will', False), False),
#   (('report', False), False),
#   (('that', True), False),
#   (('third-quarter', True), False),
#   (('profit', True), False),
#   (('rose', True), False),
#   (('more', True), True),
#   (('than', True), True),
#   (('15', True), True),
#   (('%', True), True),
#   (('from', True), True),
#   (('a', True), True),
#   (('year', True), True),
#   (('earlier', True), True),
#   ((',', False), False)],
#  [(('The', True), True),
#   (('contract', True), True),
#   (('provides', True), True),
#   (('additional', True), True),
#   (('equipment', True), True),
#   (('for', True), True),
#   (('Northrop', True), True),
#   ((',', True), False),
#   (('the', True), False),
#   (('prime', True), False),
#   (('contractor', True), False),
#   (('on', True), False),
#   (('the', True), False),
#   (('missile', True), False),
#   ((',', False), False),
#   (('and', False), False)],
#  [(('He', True), False),
#   (('said', True), False),
#   (('Gulf', True), False),
#   (('Canada', True), False),
#   (('will', True), False),
#   (('likely', True), False),
#   (('report', True), False),
#   (('an', True), False),
#   (('extraordinary', True), False),
#   (('gain', True), False),
#   (('from', True), False),
#   (('the', True), False),
#   (('sale', True), False),
#   (('in', True), False),
#   (('the', True), False),
#   (('fourth', True), False),
#   (('quarter', True), False),
#   ((',', False), False)]]
