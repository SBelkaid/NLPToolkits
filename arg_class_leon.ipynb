# %% [markdown]
# # Arg classifier

# %%
import json
from nltk.tree import Tree
from nltk.tree import ParentedTree
from collections import defaultdict

# %%
with open('conll16st-en-01-12-16-train/relations.json', encoding='utf-8') as pdtb_file:
    relations = [json.loads(x) for x in pdtb_file];
    
with open('conll16st-en-01-12-16-train/parses.json', encoding='utf8') as parse_file:
    parses = json.load(parse_file)

# %%
# We only want explicit relations:

def explicit_relations(relations):
    '''Extract all explicit relations from the relations file'''
    relations_explicit = []

    for relation in relations:
        if relation['Type'] == 'Explicit':
            relations_explicit.append(relation)
    return (relations_explicit)

ex_relations = explicit_relations(relations)

# %%
# Seperate them into PS and SS relations

def ss_ps_relations(explicit_relations):
    '''
    Sort relations into same sentence and previous sentence relations
    '''
    
    relations_ss = []
    relations_ps = []
    #relations_other = []

    for relation in explicit_relations:
        sentence_id_arg1 = relation['Arg1']['TokenList'][0][3]
        sentence_id_connective = relation['Connective']['TokenList'][0][3]
        sentence_id_arg2 = relation['Arg2']['TokenList'][0][3]
    
        if sentence_id_arg1 == sentence_id_connective == sentence_id_arg2:
            relations_ss.append(relation)
        elif int(sentence_id_arg1) == int(sentence_id_connective) - 1 == int(sentence_id_arg2) -1:
            relations_ps.append(relation)
        #else: 
            #relations_other.append(relation)
            
    return relations_ss, relations_ps

ss_relations, ps_relations = ss_ps_relations(ex_relations)

# %%
def get_phrase_structure(docID, sentenceID):
    """
    Retrieve phrase_structure from the parses.json file by filename and sentenceID.
    """
         
    sentencelist = parses[docID]["sentences"]    
    phrase_structure = sentencelist[sentenceID]["parsetree"]
    
    return phrase_structure

# %% [markdown]
# # Output format

# %%
def get_constituent(docID,sentenceID,index,pos,token):
    """
    Finds parent node of input token. 
    """
    
    phrase_structure = get_phrase_structure(docID, sentenceID)    
    tree = Tree.fromstring(phrase_structure)    
    tree = ParentedTree.convert(tree)
    
    for subtree in tree.subtrees(filter=lambda x:
                                 x.label() == pos and x[0] == token):
        return subtree.parent().label()

#get_constituent("wsj_0204",6,0,"DT","The")

# %% [markdown]
# ### SS relations

# %%
tuplelist = []

for relation in ss_relations[:20]:
    
    tokenlist = []
    
    connective = relation["Connective"]["RawText"]
    connective_index = relation["Connective"]["TokenList"][0][4]
    docID = relation["DocID"]
    
    arg1_tokenlist = relation["Arg1"]["TokenList"]
    arg2_tokenlist = relation["Arg2"]["TokenList"]
    
    #retrieve phrase structure for sentence the argument is in
    arg1_sentenceID = arg1_tokenlist[0][3]
    arg1_phrase_structure = get_phrase_structure(docID, arg1_sentenceID)
    
    arg2_sentenceID = arg2_tokenlist[0][3]
    arg2_phrase_structure = get_phrase_structure(docID, arg2_sentenceID) #should be the same
    
    
    # Build a list with indices of words in the argument
    indices = []
    
    for wordspan in arg1_tokenlist:

        index = wordspan[4]        
        indices.append(index)

        
    # Every word that precedes the connective
    word_data = parses[docID]["sentences"][arg1_sentenceID]["words"][:connective_index]
    
    for index, word in enumerate(word_data):
        
        pos = word[1]["PartOfSpeech"]
        token = word[0]
        
        if index in indices:
            argpart = True
        else:
            argpart = False
        
        constituent = get_constituent(docID,arg1_sentenceID,index,pos,token)
        
        tokenlist.append(((word[0],argpart),pos,constituent,connective))
            
    tuplelist.append(tokenlist)

# %%
tuplelist
# Out:
# [[(('Under', False), 'IN', 'PP', 'if'),
#   (('two', False), 'CD', 'NP', 'if'),
#   (('new', False), 'JJ', 'NP', 'if'),
#   (('features', False), 'NNS', 'NP', 'if'),
#   ((',', False), ',', 'S', 'if'),
#   (('participants', False), 'NNS', 'NP', 'if'),
#   (('will', False), 'MD', 'VP', 'if'),
#   (('be', False), 'VB', 'VP', 'if'),
#   (('able', False), 'JJ', 'ADJP', 'if'),
#   (('to', False), 'TO', 'VP', 'if'),
#   (('transfer', False), 'VB', 'VP', 'if'),
#   (('money', False), 'NN', 'NP', 'if'),
#   (('from', False), 'IN', 'PP', 'if'),
#   (('the', False), 'DT', 'NP', 'if'),
#   (('new', False), 'JJ', 'NP', 'if'),
#   (('funds', False), 'NNS', 'NP', 'if'),
#   (('to', False), 'TO', 'VP', 'if'),
#   (('other', False), 'JJ', 'NP', 'if'),
#   (('investment', False), 'NN', 'NP', 'if'),
#   (('funds', False), 'NNS', 'NP', 'if'),
#   (('or', True), 'CC', 'VP', 'if'),
#   ((',', False), ',', 'S', 'if')],
#  [(('Solo', True), 'NNP', 'NP', 'if'),
#   (('woodwind', True), 'JJ', 'NP', 'if'),
#   (('players', True), 'NNS', 'NP', 'if'),
#   (('have', True), 'VBP', 'VP', 'if'),
#   (('to', True), 'TO', 'VP', 'if'),
#   (('be', True), 'VB', 'VP', 'if'),
#   (('creative', True), 'JJ', 'ADJP', 'if')],
#  [(('Solo', True), 'NNP', 'NP', 'because'),
#   (('woodwind', True), 'JJ', 'NP', 'because'),
#   (('players', True), 'NNS', 'NP', 'because'),
#   (('have', True), 'VBP', 'VP', 'because'),
#   (('to', True), 'TO', 'VP', 'because'),
#   (('be', True), 'VB', 'VP', 'because'),
#   (('creative', True), 'JJ', 'ADJP', 'because'),
#   (('if', True), 'IN', 'SBAR', 'because'),
#   (('they', True), 'PRP', 'NP', 'because'),
#   (('want', True), 'VBP', 'VP', 'because'),
#   (('to', True), 'TO', 'VP', 'because'),
#   (('work', True), 'VB', 'VP', 'because'),
#   (('a', True), 'DT', 'NP', 'because'),
#   (('lot', True), 'NN', 'NP', 'because'),
#   ((',', False), ',', 'VP', 'because')],
#  [(('The', False), 'DT', 'NP', 'so'),
#   (('oboist', False), 'JJ', 'NP', 'so'),
#   (('Heinz', False), 'NNP', 'NP', 'so'),
#   (('Holliger', False), 'NNP', 'NP', 'so'),
#   (('has', False), 'VBZ', 'VP', 'so'),
#   (('taken', False), 'VBN', 'VP', 'so'),
#   (('a', False), 'DT', 'NP', 'so'),
#   (('hard', False), 'JJ', 'NP', 'so'),
#   (('line', False), 'NN', 'NP', 'so'),
#   (('about', False), 'IN', 'PP', 'so'),
#   (('the', False), 'DT', 'NP', 'so'),
#   (('problem', False), 'NN', 'NP', 'so'),
#   ((':', False), ':', 'S', 'so'),
#   (('He', True), 'PRP', 'NP', 'so'),
#   (('commissions', True), 'NNS', 'VP', 'so'),
#   (('and', True), 'CC', 'VP', 'so'),
#   (('splendidly', True), 'RB', 'ADVP', 'so'),
#   (('interprets', True), 'VBZ', 'VP', 'so'),
#   (('fearsome', True), 'JJ', 'NP', 'so'),
#   (('contemporary', True), 'JJ', 'NP', 'so'),
#   (('scores', True), 'NNS', 'NP', 'so'),
#   (('and', True), 'CC', 'VP', 'so'),
#   (('does', True), 'VBZ', 'VP', 'so'),
#   (('some', True), 'DT', 'NP', 'so'),
#   (('conducting', True), 'VBG', 'NP', 'so'),
#   ((',', False), ',', 'S', 'so')],
#  [(('Today', True), 'NN', 'NP', 'though'),
#   ((',', True), ',', 'S', 'though'),
#   (('the', True), 'DT', 'NP', 'though'),
#   (('pixie-like', True), 'JJ', 'NP', 'though'),
#   (('clarinetist', True), 'NN', 'NP', 'though'),
#   (('has', True), 'VBZ', 'VP', 'though'),
#   (('mostly', True), 'RB', 'ADVP', 'though'),
#   (('dropped', True), 'VBN', 'VP', 'though'),
#   (('the', True), 'DT', 'NP', 'though'),
#   (('missionary', True), 'JJ', 'NP', 'though'),
#   (('work', True), 'NN', 'NP', 'though'),
#   (('-LRB-', False), '-LRB-', 'PRN', 'though')],
#  [(('He', True), 'PRP', 'NP', 'and'),
#   (('believes', True), 'VBZ', 'VP', 'and'),
#   (('in', True), 'IN', 'PP', 'and'),
#   (('what', True), 'WP', 'WHNP', 'and'),
#   (('he', True), 'PRP', 'NP', 'and'),
#   (('plays', True), 'VBZ', 'VP', 'and'),
#   ((',', False), ',', 'S', 'and')],
#  [(('Clad', False), 'CC', 'S', 'and'),
#   (('in', False), 'IN', 'PP', 'and'),
#   (('his', False), 'PRP$', 'NP', 'and'),
#   (('trademark', False), 'NN', 'NP', 'and'),
#   (('black', False), 'JJ', 'NP', 'and'),
#   (('velvet', False), 'NN', 'NP', 'and'),
#   (('suit', False), 'NN', 'NP', 'and'),
#   ((',', False), ',', 'S', 'and'),
#   (('the', False), 'DT', 'NP', 'and'),
#   (('soft-spoken', False), 'JJ', 'NP', 'and'),
#   (('clarinetist', False), 'NN', 'NP', 'and'),
#   (('announced', False), 'VBD', 'VP', 'and'),
#   (('that', True), 'IN', 'SBAR', 'and'),
#   (('his', True), 'PRP$', 'NP', 'and'),
#   (('new', True), 'JJ', 'NP', 'and'),
#   (('album', True), 'NN', 'NP', 'and'),
#   ((',', True), ',', 'S', 'and'),
#   (('``', True), '``', 'NP', 'and'),
#   (('Inner', True), 'NNP', 'NP', 'and'),
#   (('Voices', True), 'NNPS', 'NP', 'and'),
#   ((',', True), ',', 'S', 'and'),
#   (("''", True), "''", 'NP', 'and'),
#   (('had', True), 'VBD', 'VP', 'and'),
#   (('just', True), 'RB', 'ADVP', 'and'),
#   (('been', True), 'VBN', 'VP', 'and'),
#   (('released', True), 'VBN', 'VP', 'and'),
#   ((',', True), ',', 'S', 'and'),
#   (('that', True), 'IN', 'SBAR', 'and'),
#   (('his', True), 'PRP$', 'NP', 'and'),
#   (('family', True), 'NN', 'NP', 'and'),
#   (('was', True), 'VBD', 'VP', 'and'),
#   (('in', True), 'IN', 'PP', 'and'),
#   (('the', True), 'DT', 'NP', 'and'),
#   (('front', True), 'JJ', 'NP', 'and'),
#   (('row', True), 'NN', 'NP', 'and'),
#   ((',', False), ',', 'S', 'and')],
#  [(('Clad', False), 'CC', 'S', 'so'),
#   (('in', False), 'IN', 'PP', 'so'),
#   (('his', False), 'PRP$', 'NP', 'so'),
#   (('trademark', False), 'NN', 'NP', 'so'),
#   (('black', False), 'JJ', 'NP', 'so'),
#   (('velvet', False), 'NN', 'NP', 'so'),
#   (('suit', False), 'NN', 'NP', 'so'),
#   ((',', False), ',', 'S', 'so'),
#   (('the', False), 'DT', 'NP', 'so'),
#   (('soft-spoken', False), 'JJ', 'NP', 'so'),
#   (('clarinetist', False), 'NN', 'NP', 'so'),
#   (('announced', False), 'VBD', 'VP', 'so'),
#   (('that', False), 'IN', 'SBAR', 'so'),
#   (('his', False), 'PRP$', 'NP', 'so'),
#   (('new', False), 'JJ', 'NP', 'so'),
#   (('album', False), 'NN', 'NP', 'so'),
#   ((',', False), ',', 'S', 'so'),
#   (('``', False), '``', 'NP', 'so'),
#   (('Inner', False), 'NNP', 'NP', 'so'),
#   (('Voices', False), 'NNPS', 'NP', 'so'),
#   ((',', False), ',', 'S', 'so'),
#   (("''", False), "''", 'NP', 'so'),
#   (('had', False), 'VBD', 'VP', 'so'),
#   (('just', False), 'RB', 'ADVP', 'so'),
#   (('been', False), 'VBN', 'VP', 'so'),
#   (('released', False), 'VBN', 'VP', 'so'),
#   ((',', False), ',', 'S', 'so'),
#   (('that', False), 'IN', 'SBAR', 'so'),
#   (('his', False), 'PRP$', 'NP', 'so'),
#   (('family', False), 'NN', 'NP', 'so'),
#   (('was', False), 'VBD', 'VP', 'so'),
#   (('in', False), 'IN', 'PP', 'so'),
#   (('the', False), 'DT', 'NP', 'so'),
#   (('front', False), 'JJ', 'NP', 'so'),
#   (('row', False), 'NN', 'NP', 'so'),
#   ((',', False), ',', 'S', 'so'),
#   (('and', True), 'CC', 'SBAR', 'so'),
#   (('that', True), 'IN', 'SBAR', 'so'),
#   (('it', True), 'PRP', 'NP', 'so'),
#   (('was', True), 'VBD', 'VP', 'so'),
#   (('his', True), 'PRP$', 'NP', 'so'),
#   (('mother', True), 'NN', 'NP', 'so'),
#   (("'s", True), 'POS', 'NP', 'so'),
#   (('birthday', True), 'NN', 'NP', 'so'),
#   ((',', False), ',', 'S', 'so')],
#  [(('Then', True), 'RB', 'ADVP', 'as if'), ((',', False), ',', 'S', 'as if')],
#  [(('Mr.', True), 'NNP', 'NP', 'then'),
#   (('Stoltzman', True), 'NNP', 'NP', 'then'),
#   (('tied', True), 'VBD', 'VP', 'then'),
#   (('the', True), 'DT', 'NP', 'then'),
#   (('composer', True), 'NN', 'NP', 'then'),
#   (('in', True), 'RP', 'PRT', 'then'),
#   (('by', True), 'IN', 'PP', 'then'),
#   (('proclaiming', True), 'VBG', 'VP', 'then'),
#   (('him', True), 'PRP', 'NP', 'then'),
#   (('``', True), '``', 'VP', 'then'),
#   (('the', True), 'DT', 'NP', 'then'),
#   (('great', True), 'JJ', 'NP', 'then'),
#   (('improviser', True), 'NN', 'NP', 'then'),
#   (('of', True), 'IN', 'PP', 'then'),
#   (('the', True), 'DT', 'NP', 'then'),
#   (('18th', True), 'JJ', 'NP', 'then'),
#   (('century', True), 'NN', 'NP', 'then'),
#   ((',', False), ',', 'VP', 'then'),
#   (("''", False), "''", 'VP', 'then'),
#   (('and', False), 'CC', 'VP', 'then')],
#  [(('Keeping', False), 'VBG', 'VP', 'then'),
#   (('the', False), 'DT', 'NP', 'then'),
#   (('mood', False), 'NN', 'NP', 'then'),
#   (('light', False), 'NN', 'NP', 'then'),
#   ((',', False), ',', 'S', 'then'),
#   (('the', True), 'DT', 'NP', 'then'),
#   (('two', True), 'CD', 'NP', 'then'),
#   (('then', True), 'RB', 'ADVP', 'then'),
#   (('chanted', True), 'VBD', 'VP', 'then'),
#   (('and', True), 'CC', 'VP', 'then'),
#   (('chortled', True), 'VBD', 'VP', 'then'),
#   (('their', True), 'PRP$', 'NP', 'then'),
#   (('way', True), 'NN', 'NP', 'then'),
#   (('through', True), 'IN', 'PP', 'then'),
#   (('some', True), 'DT', 'NP', 'then'),
#   (('murderous', True), 'JJ', 'NP', 'then'),
#   (('polyrhythms', True), 'NNS', 'NP', 'then'),
#   ((',', False), ',', 'S', 'then'),
#   (('devised', False), 'VBN', 'VP', 'then'),
#   (('by', False), 'IN', 'PP', 'then'),
#   (('Mr.', False), 'NNP', 'NP', 'then'),
#   (('Douglas', False), 'NNP', 'NP', 'then'),
#   (('as', False), 'IN', 'PP', 'then'),
#   (('an', False), 'DT', 'NP', 'then'),
#   (('alternative', False), 'NN', 'NP', 'then'),
#   (('to', False), 'TO', 'PP', 'then'),
#   (('Hindemith', False), 'NNP', 'NP', 'then'),
#   (("'s", False), 'POS', 'NP', 'then'),
#   (('dry', False), 'JJ', 'NP', 'then'),
#   (('theory-teaching', False), 'JJ', 'NP', 'then'),
#   (('techniques', False), 'NNS', 'NP', 'then'),
#   ((',', False), ',', 'S', 'then'),
#   (('and', False), 'CC', 'VP', 'then')],
#  [(('It', True), 'PRP', 'NP', 'but'),
#   (('was', True), 'VBD', 'VP', 'but'),
#   (('all', True), 'RB', 'ADJP', 'but'),
#   (('too', True), 'RB', 'ADJP', 'but'),
#   (('mellow', True), 'JJ', 'ADJP', 'but'),
#   (('to', True), 'TO', 'VP', 'but'),
#   (('be', True), 'VB', 'VP', 'but'),
#   (('believed', True), 'VBN', 'VP', 'but'),
#   ((',', False), ',', 'S', 'but')],
#  [(('Or', True), 'CC', 'SQ', 'because'),
#   (('was', True), 'VBD', 'SQ', 'because'),
#   (('it', True), 'PRP', 'NP', 'because')],
#  [(('Either', True), 'CC', 'NP', 'because'),
#   (('way', True), 'NN', 'NP', 'because'),
#   (('it', True), 'PRP', 'NP', 'because'),
#   (('was', True), 'VBD', 'VP', 'because'),
#   (('a', True), 'DT', 'NP', 'because'),
#   (('pity', True), 'NN', 'NP', 'because'),
#   ((',', False), ',', 'VP', 'because')],
#  [(('It', True), 'PRP', 'NP', 'but'),
#   (('was', True), 'VBD', 'VP', 'but'),
#   (('enjoyable', True), 'JJ', 'ADJP', 'but'),
#   (('to', True), 'TO', 'VP', 'but'),
#   (('hear', True), 'VB', 'VP', 'but'),
#   (('accomplished', True), 'VBN', 'NP', 'but'),
#   (('jazz', True), 'NN', 'NP', 'but'),
#   (('without', True), 'IN', 'PP', 'but'),
#   (('having', True), 'VBG', 'VP', 'but'),
#   (('to', True), 'TO', 'VP', 'but'),
#   (('sit', True), 'VB', 'VP', 'but'),
#   (('in', True), 'IN', 'PP', 'but'),
#   (('a', True), 'DT', 'NP', 'but'),
#   (('smoke-filled', True), 'JJ', 'NP', 'but'),
#   (('club', True), 'NN', 'NP', 'but'),
#   ((',', False), ',', 'S', 'but')],
#  [(('Managers', True), 'NNS', 'NP', 'but'),
#   (('and', True), 'CC', 'NP', 'but'),
#   (('presenters', True), 'NNS', 'NP', 'but'),
#   (('insist', True), 'VBP', 'VP', 'but'),
#   (('that', True), 'IN', 'SBAR', 'but'),
#   (('chamber', True), 'NN', 'NP', 'but'),
#   (('music', True), 'NN', 'NP', 'but'),
#   (('concerts', True), 'NNS', 'NP', 'but'),
#   (('are', True), 'VBP', 'VP', 'but'),
#   (('a', True), 'DT', 'NP', 'but'),
#   (('hard', True), 'JJ', 'NP', 'but'),
#   (('sell', True), 'NN', 'NP', 'but'),
#   ((',', False), ',', 'S', 'but')],
#  [(('Managers', False), 'NNS', 'NP', 'only if'),
#   (('and', False), 'CC', 'NP', 'only if'),
#   (('presenters', False), 'NNS', 'NP', 'only if'),
#   (('insist', False), 'VBP', 'VP', 'only if'),
#   (('that', False), 'IN', 'SBAR', 'only if'),
#   (('chamber', False), 'NN', 'NP', 'only if'),
#   (('music', False), 'NN', 'NP', 'only if'),
#   (('concerts', False), 'NNS', 'NP', 'only if'),
#   (('are', False), 'VBP', 'VP', 'only if'),
#   (('a', False), 'DT', 'NP', 'only if'),
#   (('hard', False), 'JJ', 'NP', 'only if'),
#   (('sell', False), 'NN', 'NP', 'only if'),
#   ((',', False), ',', 'S', 'only if'),
#   (('but', True), 'CC', 'S', 'only if'),
#   (('can', True), 'MD', 'SQ', 'only if'),
#   (('audiences', True), 'NNS', 'NP', 'only if'),
#   (('really', True), 'RB', 'ADVP', 'only if'),
#   (('enjoy', True), 'VB', 'VP', 'only if'),
#   (('them', True), 'PRP', 'NP', 'only if')],
#  [(('The', True), 'DT', 'NP', 'when'),
#   (('U.S.', True), 'NNP', 'NP', 'when'),
#   ((',', True), ',', 'S', 'when'),
#   (('along', True), 'IN', 'PP', 'when'),
#   (('with', True), 'IN', 'PP', 'when'),
#   (('Britain', True), 'NNP', 'NP', 'when'),
#   (('and', True), 'CC', 'NP', 'when'),
#   (('Singapore', True), 'NNP', 'NP', 'when'),
#   ((',', True), ',', 'S', 'when'),
#   (('left', True), 'VBD', 'VP', 'when'),
#   (('the', True), 'DT', 'NP', 'when'),
#   (('agency', True), 'NN', 'NP', 'when')],
#  [(('The', False), 'DT', 'NP', 'and'),
#   (('personal', False), 'JJ', 'NP', 'and'),
#   (('antics', False), 'NNS', 'NP', 'and'),
#   (('of', False), 'IN', 'PP', 'and'),
#   (('agency', False), 'NN', 'NP', 'and'),
#   (('Director', False), 'NNP', 'NP', 'and'),
#   (('Amadou-Mahtar', False), 'NNP', 'NP', 'and'),
#   (("M'Bow", False), 'NNP', 'NP', 'and'),
#   (('drew', False), 'VBD', 'VP', 'and'),
#   (('much', False), 'JJ', 'NP', 'and'),
#   (('attention', False), 'NN', 'NP', 'and'),
#   ((',', False), ',', 'NP', 'and'),
#   (('such', False), 'JJ', 'PP', 'and'),
#   (('as', False), 'IN', 'PP', 'and'),
#   (('when', True), 'WRB', 'WHADVP', 'and'),
#   (('several', True), 'JJ', 'NP', 'and'),
#   (('of', True), 'IN', 'PP', 'and'),
#   (('his', True), 'PRP$', 'NP', 'and'),
#   (('top', True), 'JJ', 'NP', 'and'),
#   (('aides', True), 'NNS', 'NP', 'and'),
#   (('were', True), 'VBD', 'VP', 'and'),
#   (('uncovered', True), 'VBN', 'VP', 'and'),
#   (('as', True), 'IN', 'PP', 'and'),
#   (('KGB', True), 'NNP', 'NP', 'and'),
#   (('plants', True), 'NNS', 'NP', 'and'),
#   (('and', True), 'CC', 'VP', 'and'),
#   (('ejected', True), 'VBN', 'VP', 'and'),
#   (('from', True), 'IN', 'PP', 'and'),
#   (('France', True), 'NNP', 'NP', 'and')],
#  [(('The', True), 'DT', 'NP', 'when'),
#   (('personal', True), 'JJ', 'NP', 'when'),
#   (('antics', True), 'NNS', 'NP', 'when'),
#   (('of', True), 'IN', 'PP', 'when'),
#   (('agency', True), 'NN', 'NP', 'when'),
#   (('Director', True), 'NNP', 'NP', 'when'),
#   (('Amadou-Mahtar', True), 'NNP', 'NP', 'when'),
#   (("M'Bow", True), 'NNP', 'NP', 'when'),
#   (('drew', True), 'VBD', 'VP', 'when'),
#   (('much', True), 'JJ', 'NP', 'when'),
#   (('attention', True), 'NN', 'NP', 'when'),
#   ((',', False), ',', 'NP', 'when'),
#   (('such', False), 'JJ', 'PP', 'when'),
#   (('as', False), 'IN', 'PP', 'when'),
#   (('when', False), 'WRB', 'WHADVP', 'when'),
#   (('several', False), 'JJ', 'NP', 'when'),
#   (('of', False), 'IN', 'PP', 'when'),
#   (('his', False), 'PRP$', 'NP', 'when'),
#   (('top', False), 'JJ', 'NP', 'when'),
#   (('aides', False), 'NNS', 'NP', 'when'),
#   (('were', False), 'VBD', 'VP', 'when'),
#   (('uncovered', False), 'VBN', 'VP', 'when'),
#   (('as', False), 'IN', 'PP', 'when'),
#   (('KGB', False), 'NNP', 'NP', 'when'),
#   (('plants', False), 'NNS', 'NP', 'when'),
#   (('and', False), 'CC', 'VP', 'when'),
#   (('ejected', False), 'VBN', 'VP', 'when'),
#   (('from', False), 'IN', 'PP', 'when'),
#   (('France', False), 'NNP', 'NP', 'when'),
#   (('and', False), 'CC', 'VP', 'when')]]

# %% [markdown]
# ### PS relations

# %%
tuplelist = []

for relation in ps_relations[:2]:
    
    tokenlist = []
    
    connective = relation["Connective"]["RawText"]
    connective_index = relation["Connective"]["TokenList"][0][4]
    docID = relation["DocID"]
    
    arg1_tokenlist = relation["Arg1"]["TokenList"]
    arg2_tokenlist = relation["Arg2"]["TokenList"]
    
    #retrieve phrase structure for sentence the argument is in
    arg1_sentenceID = arg1_tokenlist[0][3]
    arg1_phrase_structure = get_phrase_structure(docID, arg1_sentenceID)
    
    arg2_sentenceID = arg2_tokenlist[0][3]
    arg2_phrase_structure = get_phrase_structure(docID, arg2_sentenceID)
    
    
    # Build a list with indices of words in the argument
    indices = []
    
    for wordspan in arg1_tokenlist:

        index = wordspan[4]        
        indices.append(index)

        
    # Every word in the sentence 
    word_data = parses[docID]["sentences"][arg1_sentenceID]["words"]
    
    for index, word in enumerate(word_data):
        
        pos = word[1]["PartOfSpeech"]
        token = word[0]
        
        if index in indices:
            argpart = True
        else:
            argpart = False
        
        constituent = get_constituent(docID,arg1_sentenceID,index,pos,token)
        
        tokenlist.append(((word[0],argpart),pos,constituent,connective))
            
    tuplelist.append(tokenlist)

# %%
tuplelist
# Out:
# [[(('The', True), 'DT', 'NP', 'Also'),
#   (('new', True), 'JJ', 'NP', 'Also'),
#   (('``', True), '``', 'NP', 'Also'),
#   (('social', True), 'JJ', 'NP', 'Also'),
#   (('choice', True), 'NN', 'NP', 'Also'),
#   (("''", True), "''", 'NP', 'Also'),
#   (('fund', True), 'NN', 'NP', 'Also'),
#   (('will', True), 'MD', 'VP', 'Also'),
#   (('shun', True), 'VB', 'VP', 'Also'),
#   (('securities', True), 'NNS', 'NP', 'Also'),
#   (('of', True), 'IN', 'PP', 'Also'),
#   (('companies', True), 'NNS', 'NP', 'Also'),
#   (('linked', True), 'VBN', 'VP', 'Also'),
#   (('to', True), 'TO', 'PP', 'Also'),
#   (('South', True), 'NNP', 'NP', 'Also'),
#   (('Africa', True), 'NNP', 'NP', 'Also'),
#   ((',', True), ',', 'NP', 'Also'),
#   (('nuclear', True), 'JJ', 'NP', 'Also'),
#   (('power', True), 'NN', 'NP', 'Also'),
#   (('and', True), 'CC', 'NP', 'Also'),
#   (('in', True), 'IN', 'PP', 'Also'),
#   (('some', True), 'DT', 'NP', 'Also'),
#   (('cases', True), 'NNS', 'NP', 'Also'),
#   ((',', True), ',', 'NP', 'Also'),
#   (('Northern', True), 'NNP', 'NP', 'Also'),
#   (('Ireland', True), 'NNP', 'NP', 'Also'),
#   (('.', False), '.', 'S', 'Also')],
#  [(('The', True), 'DT', 'NP', 'also'),
#   (('bond', True), 'NN', 'NP', 'also'),
#   (('fund', True), 'NN', 'NP', 'also'),
#   (('will', True), 'MD', 'VP', 'also'),
#   (('invest', True), 'VB', 'VP', 'also'),
#   (('in', True), 'IN', 'PP', 'also'),
#   (('high-grade', True), 'JJ', 'ADJP', 'also'),
#   (('or', True), 'CC', 'ADJP', 'also'),
#   (('medium-grade', True), 'JJ', 'ADJP', 'also'),
#   (('bonds', True), 'NNS', 'NP', 'also'),
#   ((',', True), ',', 'NP', 'also'),
#   (('mortgages', True), 'NNS', 'NP', 'also'),
#   (('or', True), 'CC', 'ADJP', 'also'),
#   (('asset-backed', True), 'JJ', 'NP', 'also'),
#   (('securities', True), 'NNS', 'NP', 'also'),
#   ((',', True), ',', 'NP', 'also'),
#   (('including', True), 'VBG', 'PP', 'also'),
#   (('as', True), 'RB', 'QP', 'also'),
#   (('much', True), 'JJ', 'QP', 'also'),
#   (('as', True), 'IN', 'QP', 'also'),
#   (('15', True), 'CD', 'QP', 'also'),
#   (('%', True), 'NN', 'NP', 'also'),
#   (('in', True), 'IN', 'PP', 'also'),
#   (('foreign', True), 'JJ', 'NP', 'also'),
#   (('securities', True), 'NNS', 'NP', 'also'),
#   (('.', False), '.', 'S', 'also')]]
